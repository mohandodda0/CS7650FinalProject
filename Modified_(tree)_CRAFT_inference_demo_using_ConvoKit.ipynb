# %% [markdown]
# # CRAFT demo (inference only) using ConvoKit
#
# This example notebook shows how an already-trained CRAFT model performs in predicting future derailment. This example is an adaptation of the demo notebook provided by the authors of the "Trouble on the Horizon" paper, and uses ConvoKit's version of the labeled Wikiconv corpus.

# %%
# start by installing ConvoKit on the colab VM
# !pip install -q convokit
# Out:
#      |████████████████████████████████| 167 kB 12.6 MB/s
#      |████████████████████████████████| 6.0 MB 24.5 MB/s
#      |████████████████████████████████| 1.5 MB 44.3 MB/s
#      |████████████████████████████████| 235 kB 30.8 MB/s
#      |████████████████████████████████| 170 kB 49.8 MB/s
#      |████████████████████████████████| 64 kB 2.7 MB/s
#      |████████████████████████████████| 749 kB 41.3 MB/s
#      |████████████████████████████████| 181 kB 52.2 MB/s
#      |████████████████████████████████| 10.1 MB 32.0 MB/s
#      |████████████████████████████████| 451 kB 51.4 MB/s
#      |████████████████████████████████| 628 kB 48.3 MB/s
#      |████████████████████████████████| 42 kB 1.3 MB/s
#   Building wheel for convokit (setup.py) ... done
#   Building wheel for ftfy (setup.py) ... done
#   Building wheel for emoji (setup.py) ... done

# %%
# import necessary libraries, including convokit
import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
import requests
import os
import sys
import random
import unicodedata
import itertools
from urllib.request import urlretrieve
from convokit import download, Corpus, Conversation
# %matplotlib inline

# %%
# define globals and constants

MAX_LENGTH = 80  # Maximum sentence length (number of tokens) to consider

# configure model
num_classes = 2
hidden_size = 500
encoder_n_layers = 2
context_encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64
# Configure training/optimization
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
labeled_learning_rate = 1e-5
decoder_learning_ratio = 5.0
print_every = 10

# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token
UNK_token = 3  # Unknown word token

# model download paths
WORD2INDEX_URL = "http://zissou.infosci.cornell.edu/convokit/models/craft_wikiconv/word2index.json"
INDEX2WORD_URL = "http://zissou.infosci.cornell.edu/convokit/models/craft_wikiconv/index2word.json"
MODEL_URL = "http://zissou.infosci.cornell.edu/convokit/models/craft_wikiconv/craft_full.tar"

# confidence score threshold for declaring a positive prediction.
# this value was previously learned on the validation set.
FORECAST_THRESH = 0.570617

# %% [markdown]
# ## Part 1: set up data conversion utilities
#
# We begin by setting up some helper functions and classes for converting conversational text data into a torch-friendly Tensor format. Note that these low-level routines are largely taken from the [PyTorch seq2seq chatbot tutorial](https://pytorch.org/tutorials/beginner/chatbot_tutorial.html).

# %%
class Voc:
    """A class for representing the vocabulary used by a CRAFT model"""

    def __init__(self, name, word2index=None, index2word=None):
        self.name = name
        self.trimmed = False if not word2index else True # if a precomputed vocab is specified assume the user wants to use it as-is
        self.word2index = word2index if word2index else {"UNK": UNK_token}
        self.word2count = {}
        self.index2word = index2word if index2word else {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS", UNK_token: "UNK"}
        self.num_words = 4 if not index2word else len(index2word)  # Count SOS, EOS, PAD, UNK

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {"UNK": UNK_token}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS", UNK_token: "UNK"}
        self.num_words = 4 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# Create a Voc object from precomputed data structures
def loadPrecomputedVoc(corpus_name, word2index_url, index2word_url):
    # load the word-to-index lookup map
    r = requests.get(word2index_url)
    word2index = r.json()
    # load the index-to-word lookup map
    r = requests.get(index2word_url)
    index2word = r.json()
    return Voc(corpus_name, word2index, index2word)

# %%
# Helper functions for preprocessing and tokenizing text

# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Tokenize the string using NLTK
def tokenize(text):
    tokenizer = nltk.tokenize.RegexpTokenizer(pattern=r'\w+|[^\w\s]')
    # simplify the problem space by considering only ASCII data
    cleaned_text = unicodeToAscii(text.lower())

    # if the resulting string is empty, nothing else to do
    if not cleaned_text.strip():
        return []
    
    return tokenizer.tokenize(cleaned_text)

# Given a ConvoKit conversation, preprocess each utterance's text by tokenizing and truncating.
# Returns the processed dialog entry where text has been replaced with a list of
# tokens, each no longer than MAX_LENGTH - 1 (to leave space for the EOS token)
def processDialog(voc, dialog):
    processed = []
    for utterance in dialog.iter_utterances():
        tokens = tokenize(utterance.text)
        # replace out-of-vocabulary tokens
        for i in range(len(tokens)):
            if tokens[i] not in voc.word2index:
                tokens[i] = "UNK"
        processed.append({"tokens": tokens, "is_attack": int(utterance.meta['comment_has_personal_attack']), "id": utterance.id})
    return processed

# Load context-reply pairs from the Corpus, optionally filtering to only conversations
# from the specified split (train, val, or test).
# Each conversation, which has N comments (not including the section header) will
# get converted into N-1 comment-reply pairs, one pair for each reply 
# (the first comment does not reply to anything).
# Each comment-reply pair is a tuple consisting of the conversational context
# (that is, all comments prior to the reply), the reply itself, the label (that
# is, whether the reply contained a derailment event), and the comment ID of the
# reply (for later use in re-joining with the ConvoKit corpus).
# The function returns a list of such pairs.
def loadPairs(voc, corpus, split=None, last_only=False):
    pairs = []
    for convo in corpus.iter_conversations():
        # consider only conversations in the specified split of the data
        if (split is None or convo.meta['split'] == split):
            dialog = processDialog(voc, convo)
            iter_range = range(1, len(dialog)) if not last_only else [len(dialog)-1]
            for idx in iter_range:
                reply = dialog[idx]["tokens"][:(MAX_LENGTH-1)]
                label = dialog[idx]["is_attack"]
                comment_id = dialog[idx]["id"]
                # gather as context all utterances preceding the reply
                context = [u["tokens"][:(MAX_LENGTH-1)] for u in dialog[:idx]]
                pairs.append((context, reply, label, comment_id))
    return pairs

# %%
# Helper functions for turning dialog and text sequences into tensors, and manipulating those tensors

def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence] + [EOS_token]

def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# Takes a batch of dialogs (lists of lists of tokens) and converts it into a
# batch of utterances (lists of tokens) sorted by length, while keeping track of
# the information needed to reconstruct the original batch of dialogs
def dialogBatch2UtteranceBatch(dialog_batch):
    utt_tuples = [] # will store tuples of (utterance, original position in batch, original position in dialog)
    for batch_idx in range(len(dialog_batch)):
        dialog = dialog_batch[batch_idx]
        for dialog_idx in range(len(dialog)):
            utterance = dialog[dialog_idx]
            utt_tuples.append((utterance, batch_idx, dialog_idx))
    # sort the utterances in descending order of length, to remain consistent with pytorch padding requirements
    utt_tuples.sort(key=lambda x: len(x[0]), reverse=True)
    # return the utterances, original batch indices, and original dialog indices as separate lists
    utt_batch = [u[0] for u in utt_tuples]
    batch_indices = [u[1] for u in utt_tuples]
    dialog_indices = [u[2] for u in utt_tuples]
    return utt_batch, batch_indices, dialog_indices

# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.ByteTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# Returns all items for a given batch of pairs
def batch2TrainData(voc, pair_batch, already_sorted=False):
    if not already_sorted:
        pair_batch.sort(key=lambda x: len(x[0]), reverse=True)
    input_batch, output_batch, label_batch, id_batch = [], [], [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
        label_batch.append(pair[2])
        id_batch.append(pair[3])
    dialog_lengths = torch.tensor([len(x) for x in input_batch])
    input_utterances, batch_indices, dialog_indices = dialogBatch2UtteranceBatch(input_batch)
    inp, utt_lengths = inputVar(input_utterances, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    label_batch = torch.FloatTensor(label_batch) if label_batch[0] is not None else None
    return inp, dialog_lengths, utt_lengths, batch_indices, dialog_indices, label_batch, id_batch, output, mask, max_target_len

def batchIterator(voc, source_data, batch_size, shuffle=True):
    cur_idx = 0
    if shuffle:
        random.shuffle(source_data)
    while True:
        if cur_idx >= len(source_data):
            cur_idx = 0
            if shuffle:
                random.shuffle(source_data)
        batch = source_data[cur_idx:(cur_idx+batch_size)]
        # the true batch size may be smaller than the given batch size if there is not enough data left
        true_batch_size = len(batch)
        # ensure that the dialogs in this batch are sorted by length, as expected by the padding module
        batch.sort(key=lambda x: len(x[0]), reverse=True)
        # for analysis purposes, get the source dialogs and labels associated with this batch
        batch_dialogs = [x[0] for x in batch]
        batch_labels = [x[2] for x in batch]
        # convert batch to tensors
        batch_tensors = batch2TrainData(voc, batch, already_sorted=True)
        yield (batch_tensors, batch_dialogs, batch_labels, true_batch_size) 
        cur_idx += batch_size

# %% [markdown]
# ## Part 2: load the data
#
# Now we load the labeled Wikiconv corpus from ConvoKit, and run some transformations to prepare it for use with PyTorch

# %%
corpus = Corpus(filename=download("conversations-gone-awry-corpus"))
#corpus_for_extended_model = Corpus(filename=download("conversations-gone-awry-cmv-corpus"))
# Out:
# Downloading conversations-gone-awry-corpus to /root/.convokit/downloads/conversations-gone-awry-corpus
# Downloading conversations-gone-awry-corpus from http://zissou.infosci.cornell.edu/convokit/datasets/conversations-gone-awry-corpus/conversations-gone-awry-corpus.zip (45.2MB)... Done

# %% [markdown]
# # Rough cells for data labeling
#
# The following 3 cells can be used for data labeling. We can 100% do this before linearizing the conversations to avoid redundancy.

# %%
# Both corpuses we are interested in already have train/val/test splits. We can use this while labeling to make sure we label conversations belonging to all 3 categories
#corpus.filter_conversations_by(lambda convo: convo.meta['split'] == 'train')

# %%
#convos_evaluated = []

# %%
# here is rough code to assign labels into the data. We may use this, we may use something else. Regardless we will
# WANT TO BE SURE WE SAVE AND DOWNLOAD any work we run on colab
#last_conversation = 0
#inp = ''
#while inp != 'stop':
#  convo = corpus.get_conversation(corpus.get_conversation_ids()[last_conversation])
#  #convo.print_conversation_structure(lambda utt: utt.id + "   " + utt.text[:50] + "\n")
#  utterances = convo.get_utterance_ids()
#  while len(utterances) > 20:
#    last_conversation += 1
#    convo = corpus.get_conversation(corpus.get_conversation_ids()[last_conversation])
#    utterances = convo.get_utterance_ids()
#  for utt in utterances:
#    utt_data = corpus.get_utterance(utt)
#    inp = ''
#    while inp not in ['stop', 'y', 'n', 'r']:
#      print(utt_data.text)
#      inp = input(utt+'  '+utt_data.speaker.id+'  Personal Attack?: ')
#      if inp == 'y':
#        utt_data.meta['comment_has_personal_attack'] = True
#      elif inp == 'n':
#        utt_data.meta['comment_has_personal_attack'] = False
#    if inp == 'stop':
#      break
#  convos_evaluated.append(convon)
#  last_conversation += 1
#  print('Currently in conversation ',last_conversation)

# %%
# let's check some quick stats to verify that the corpus loaded correctly
print(len(corpus.get_utterance_ids()))
print(len(corpus.get_usernames()))
print(len(corpus.get_conversation_ids()))
# Out:
# 30021
# 8069
# 4188
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: get_usernames() is deprecated and will be removed in a future release. Use get_speaker_ids() instead.

# %%
# Let's also take a look at some example data to see what kinds of information/metadata are available to us
print(list(corpus.iter_conversations())[0].__dict__)
print(list(corpus.iter_utterances())[0])
# Out:
# {'obj_type': 'conversation', '_owner': <convokit.model.corpus.Corpus object at 0x7f2bbf343750>, 'meta': {'page_title': 'User talk:2005', 'page_id': 1003212, 'pair_id': '143890867.11926.11926', 'conversation_has_personal_attack': False, 'verified': True, 'pair_verified': True, 'annotation_year': '2018', 'split': 'train'}, '_id': '146743638.12652.12652', 'vectors': [], '_utterance_ids': ['146743638.12652.12652', '146743638.12667.12652', '146842219.12874.12874', '146860774.13072.13072'], '_speaker_ids': None, 'tree': None}
# Utterance(id: '146743638.12652.12652', conversation_id: 146743638.12652.12652, reply-to: None, speaker: Speaker(id: Sirex98, vectors: [], meta: {}), timestamp: 1185295934.0, text: '== [WIKI_LINK: WP:COMMONNAME] ==\n', vectors: [], meta: {'is_section_header': True, 'comment_has_personal_attack': False, 'toxicity': 0, 'parsed': [{'rt': 3, 'toks': [{'tok': '=', 'tag': 'NFP', 'dep': 'punct', 'up': 3, 'dn': []}, {'tok': '=', 'tag': 'LS', 'dep': 'punct', 'up': 3, 'dn': []}, {'tok': '[', 'tag': '-LRB-', 'dep': 'punct', 'up': 3, 'dn': []}, {'tok': 'WIKI_LINK', 'tag': 'JJ', 'dep': 'ROOT', 'dn': [0, 1, 2, 4]}, {'tok': ':', 'tag': ':', 'dep': 'punct', 'up': 3, 'dn': []}]}, {'rt': 0, 'toks': [{'tok': 'WP', 'tag': 'NNP', 'dep': 'ROOT', 'dn': [1, 2, 5]}, {'tok': ':', 'tag': ':', 'dep': 'punct', 'up': 0, 'dn': []}, {'tok': 'COMMONNAME', 'tag': 'NNPS', 'dep': 'appos', 'up': 0, 'dn': [3]}, {'tok': ']', 'tag': '-RRB-', 'dep': 'punct', 'up': 2, 'dn': []}, {'tok': '=', 'tag': 'SYM', 'dep': 'punct', 'up': 5, 'dn': []}, {'tok': '=', 'tag': 'SYM', 'dep': 'punct', 'up': 0, 'dn': [4, 6]}, {'tok': '\n', 'tag': '', 'dep': '', 'up': 5, 'dn': []}]}]})

# %% [markdown]
# Now we can use the utilities defined in Part 1 to convert the ConvoKit conversational data into a tokenized form that can be straightforwardly turned into Tensors later.

# %%
# First, we need to build the vocabulary so that we know how to map tokens to tensor indicies.
# For the sake of replicating the paper results, we will load the pre-computed vocabulary objects used in the paper.
voc = loadPrecomputedVoc("wikiconv", WORD2INDEX_URL, INDEX2WORD_URL)

# %%
# Inspect the Voc object to make sure it loaded correctly
print(voc.num_words) # expected vocab size is 50004: it was built using a fixed vocab size of 50k plus 4 spots for special tokens PAD, SOS, EOS, and UNK.
print(list(voc.word2index.items())[:10])
print(list(voc.index2word.items())[:10])
# Out:
# 50004
# [('UNK', 3), ('.', 4), ('the', 5), ("'", 6), (',', 7), ('to', 8), ('i', 9), ('of', 10), ('a', 11), ('and', 12)]
# [('0', 'PAD'), ('1', 'SOS'), ('2', 'EOS'), ('3', 'UNK'), ('4', '.'), ('5', 'the'), ('6', "'"), ('7', ','), ('8', 'to'), ('9', 'i')]

# %%
# Convert the test set data into a list of input/label pairs. Each input will represent the conversation as a list of lists of tokens.
train_pairs = loadPairs(voc, corpus, "train", last_only=True)
val_pairs = loadPairs(voc, corpus, "val", last_only=True)
test_pairs = loadPairs(voc, corpus, "test")
# Out:
# Streaming output truncated to the last 5000 lines.
# Checking reply-to chain of Conversation 234044712.9032.9032
# No issues found.
#
# Checking reply-to chain of Conversation 269894650.1070.1070
# No issues found.
#
# Checking reply-to chain of Conversation 331652375.7889.7889
# No issues found.
#
# Checking reply-to chain of Conversation 124154930.215277.215211
# No issues found.
#
# Checking reply-to chain of Conversation 124113023.188154.188154
# No issues found.
#
# Checking reply-to chain of Conversation 692819984.2913.2913
# No issues found.
#
# Checking reply-to chain of Conversation 844595084.6611.6611
# No issues found.
#
# Checking reply-to chain of Conversation 204198724.11060.11060
# No issues found.
#
# Checking reply-to chain of Conversation 204031305.3894.3894
# No issues found.
#
# Checking reply-to chain of Conversation 62900025.41968.41968
# No issues found.
#
# Checking reply-to chain of Conversation 62890334.37191.37191
# No issues found.
#
# Checking reply-to chain of Conversation 12187886.141625.141625
# No issues found.
#
# Checking reply-to chain of Conversation 12167159.136543.136543
# No issues found.
#
# Checking reply-to chain of Conversation 610398358.41338.41338
# No issues found.
#
# Checking reply-to chain of Conversation 658690366.54380.54380
# No issues found.
#
# Checking reply-to chain of Conversation 737281330.51355.51355
# No issues found.
#
# Checking reply-to chain of Conversation 736584451.26085.26085
# No issues found.
#
# Checking reply-to chain of Conversation 800747251.13038.13038
# No issues found.
#
# Checking reply-to chain of Conversation 800767638.13828.13828
# No issues found.
#
# Checking reply-to chain of Conversation 130142184.21.21
# No issues found.
#
# Checking reply-to chain of Conversation 163175449.27490.27490
# No issues found.
#
# Checking reply-to chain of Conversation 607457423.100895.100895
# No issues found.
#
# Checking reply-to chain of Conversation 607273760.94914.94914
# No issues found.
#
# Checking reply-to chain of Conversation 440473971.63224.63224
# No issues found.
#
# Checking reply-to chain of Conversation 439473115.92051.92051
# No issues found.
#
# Checking reply-to chain of Conversation 141419850.58.58
# WARNING: ERROR: Missing utterance 141419850.58.58
# Checking reply-to chain of Conversation 139791766.42165.42165
# No issues found.
#
# Checking reply-to chain of Conversation 133521396.42249.42249
# WARNING: ERROR: Missing utterance 133521396.42249.42249
# Checking reply-to chain of Conversation 133459967.17746.17746
# No issues found.
#
# Checking reply-to chain of Conversation 136289256.2567.2567
# No issues found.
#
# Checking reply-to chain of Conversation 136312321.4971.4971
# No issues found.
#
# Checking reply-to chain of Conversation 120691935.319.319
# No issues found.
#
# Checking reply-to chain of Conversation 34364810.2636.2636
# No issues found.
#
# Checking reply-to chain of Conversation 133943876.10370.10370
# No issues found.
#
# Checking reply-to chain of Conversation 133814486.1212.1212
# No issues found.
#
# Checking reply-to chain of Conversation 43509832.76095.76095
# No issues found.
#
# Checking reply-to chain of Conversation 84963583.30826.30826
# No issues found.
#
# Checking reply-to chain of Conversation 38910400.178073.178073
# No issues found.
#
# Checking reply-to chain of Conversation 37192162.56808.56808
# No issues found.
#
# Checking reply-to chain of Conversation 498582193.80254.80254
# No issues found.
#
# Checking reply-to chain of Conversation 500004279.105162.105162
# No issues found.
#
# Checking reply-to chain of Conversation 502326031.11981.11980
# No issues found.
#
# Checking reply-to chain of Conversation 502063894.5884.5884
# No issues found.
#
# Checking reply-to chain of Conversation 375594395.80054.80054
# No issues found.
#
# Checking reply-to chain of Conversation 376718309.90935.90935
# No issues found.
#
# Checking reply-to chain of Conversation 63149621.0.0
# No issues found.
#
# Checking reply-to chain of Conversation 421107815.47641.47641
# No issues found.
#
# Checking reply-to chain of Conversation 546557839.9783.9783
# No issues found.
#
# Checking reply-to chain of Conversation 546756837.15914.15914
# No issues found.
#
# Checking reply-to chain of Conversation 238600569.11532.11532
# No issues found.
#
# Checking reply-to chain of Conversation 238492210.10461.10461
# No issues found.
#
# Checking reply-to chain of Conversation 225472200.53026.53026
# No issues found.
#
# Checking reply-to chain of Conversation 215736273.34953.34953
# No issues found.
#
# Checking reply-to chain of Conversation 706098253.197028.197028
# No issues found.
#
# Checking reply-to chain of Conversation 700313242.38347.38343
# WARNING: ERROR: Missing utterance 700313242.38347.38343
# Checking reply-to chain of Conversation 147033805.6582.6582
# No issues found.
#
# Checking reply-to chain of Conversation 146914192.568.568
# No issues found.
#
# Checking reply-to chain of Conversation 665641194.121652.121652
# No issues found.
#
# Checking reply-to chain of Conversation 665450405.119557.119557
# No issues found.
#
# Checking reply-to chain of Conversation 144114634.402.402
# No issues found.
#
# Checking reply-to chain of Conversation 603847875.10307.10307
# No issues found.
#
# Checking reply-to chain of Conversation 7991328.294.294
# WARNING: ERROR: Missing utterance 8728710.3118.5498
# Checking reply-to chain of Conversation 64299305.77889.77889
# No issues found.
#
# Checking reply-to chain of Conversation 115486269.9877.9877
# No issues found.
#
# Checking reply-to chain of Conversation 37617534.406.406
# No issues found.
#
# Checking reply-to chain of Conversation 160137511.19368.19368
# No issues found.
#
# Checking reply-to chain of Conversation 156423632.13021.13021
# No issues found.
#
# Checking reply-to chain of Conversation 327532554.4437.4437
# No issues found.
#
# Checking reply-to chain of Conversation 675926428.11822.11822
# No issues found.
#
# Checking reply-to chain of Conversation 8261330.931.931
# No issues found.
#
# Checking reply-to chain of Conversation 8372529.16092.16038
# No issues found.
#
# Checking reply-to chain of Conversation 50282134.86214.86214
# No issues found.
#
# Checking reply-to chain of Conversation 50087684.77894.77894
# No issues found.
#
# Checking reply-to chain of Conversation 67979393.20619.20619
# No issues found.
#
# Checking reply-to chain of Conversation 74249038.29166.29166
# No issues found.
#
# Checking reply-to chain of Conversation 63190280.43932.43932
# No issues found.
#
# Checking reply-to chain of Conversation 63014639.42624.42624
# No issues found.
#
# Checking reply-to chain of Conversation 83888519.102297.102297
# No issues found.
#
# Checking reply-to chain of Conversation 31546988.15224.15224
# No issues found.
#
# Checking reply-to chain of Conversation 35600722.17898.17898
# No issues found.
#
# Checking reply-to chain of Conversation 35705418.23640.23640
# No issues found.
#
# Checking reply-to chain of Conversation 163003106.19300.19300
# WARNING: ERROR: Missing utterance 163005226.19559.19580
# Checking reply-to chain of Conversation 160083042.10242.10242
# No issues found.
#
# Checking reply-to chain of Conversation 52636561.7569.7569
# No issues found.
#
# Checking reply-to chain of Conversation 53389590.18899.18899
# No issues found.
#
# Checking reply-to chain of Conversation 31469505.2665.2665
# No issues found.
#
# Checking reply-to chain of Conversation 331165989.12683.12683
# No issues found.
#
# Checking reply-to chain of Conversation 491717077.5769.5769
# No issues found.
#
# Checking reply-to chain of Conversation 646528322.20758.20758
# No issues found.
#
# Checking reply-to chain of Conversation 153440869.6771.6771
# No issues found.
#
# Checking reply-to chain of Conversation 150472995.0.0
# WARNING: ERROR: Missing utterance 150472995.0.0
# Checking reply-to chain of Conversation 750045303.8424.8424
# No issues found.
#
# Checking reply-to chain of Conversation 650162047.43690.43690
# No issues found.
#
# Checking reply-to chain of Conversation 2794797.75760.75760
# No issues found.
#
# Checking reply-to chain of Conversation 2836019.94718.94718
# No issues found.
#
# Checking reply-to chain of Conversation 158896237.30394.30394
# No issues found.
#
# Checking reply-to chain of Conversation 153330733.24064.24064
# No issues found.
#
# Checking reply-to chain of Conversation 497449639.16997.16997
# No issues found.
#
# Checking reply-to chain of Conversation 497525772.27126.27094
# No issues found.
#
# Checking reply-to chain of Conversation 144400646.123809.123809
# No issues found.
#
# Checking reply-to chain of Conversation 135561509.118549.118549
# No issues found.
#
# Checking reply-to chain of Conversation 335299044.9453.9453
# No issues found.
#
# Checking reply-to chain of Conversation 344764263.3428.3428
# No issues found.
#
# Checking reply-to chain of Conversation 153999042.1460.1460
# No issues found.
#
# Checking reply-to chain of Conversation 155967496.26842.26842
# No issues found.
#
# Checking reply-to chain of Conversation 630540539.22902.22902
# No issues found.
#
# Checking reply-to chain of Conversation 48018847.2183.2182
# No issues found.
#
# Checking reply-to chain of Conversation 428667627.34242.34242
# No issues found.
#
# Checking reply-to chain of Conversation 496126690.20074.20074
# No issues found.
#
# Checking reply-to chain of Conversation 593959411.53816.53816
# No issues found.
#
# Checking reply-to chain of Conversation 593962760.54308.54308
# No issues found.
#
# Checking reply-to chain of Conversation 599360441.31464.31464
# No issues found.
#
# Checking reply-to chain of Conversation 599580710.57069.57069
# No issues found.
#
# Checking reply-to chain of Conversation 754268732.5523.5523
# No issues found.
#
# Checking reply-to chain of Conversation 754378495.11046.11046
# No issues found.
#
# Checking reply-to chain of Conversation 209122887.102328.102328
# No issues found.
#
# Checking reply-to chain of Conversation 209435673.117146.117146
# No issues found.
#
# Checking reply-to chain of Conversation 844101922.54990.54990
# No issues found.
#
# Checking reply-to chain of Conversation 790211260.47074.47074
# No issues found.
#
# Checking reply-to chain of Conversation 157729763.7883.7883
# No issues found.
#
# Checking reply-to chain of Conversation 124704533.3729.3729
# No issues found.
#
# Checking reply-to chain of Conversation 392033231.4852.4852
# No issues found.
#
# Checking reply-to chain of Conversation 395237625.22076.22076
# No issues found.
#
# Checking reply-to chain of Conversation 345867158.10705.10705
# No issues found.
#
# Checking reply-to chain of Conversation 345865796.10109.10109
# No issues found.
#
# Checking reply-to chain of Conversation 200634239.56463.56463
# No issues found.
#
# Checking reply-to chain of Conversation 198688208.49744.49744
# No issues found.
#
# Checking reply-to chain of Conversation 484796662.8189.8712
# No issues found.
#
# Checking reply-to chain of Conversation 507156034.16735.16735
# No issues found.
#
# Checking reply-to chain of Conversation 229244668.21544.21544
# No issues found.
#
# Checking reply-to chain of Conversation 228590201.10821.10821
# No issues found.
#
# Checking reply-to chain of Conversation 102012975.186434.186434
# No issues found.
#
# Checking reply-to chain of Conversation 101988830.174339.174339
# No issues found.
#
# Checking reply-to chain of Conversation 24319777.0.0
# WARNING: ERROR: Missing utterance 24516082.2.34017
# WARNING: ERROR: Missing utterance 24328953.2.20600
# Checking reply-to chain of Conversation 57195711.13937.13937
# No issues found.
#
# Checking reply-to chain of Conversation 23524583.21868.21868
# No issues found.
#
# Checking reply-to chain of Conversation 24635104.25085.25085
# WARNING: ERROR: Missing utterance 24635104.25085.25085
# Checking reply-to chain of Conversation 350919846.97689.97689
# No issues found.
#
# Checking reply-to chain of Conversation 279283652.77456.77456
# No issues found.
#
# Checking reply-to chain of Conversation 350236750.83554.83562
# No issues found.
#
# Checking reply-to chain of Conversation 277910237.62434.62434
# No issues found.
#
# Checking reply-to chain of Conversation 312844590.31027.31027
# No issues found.
#
# Checking reply-to chain of Conversation 427518180.34356.34356
# No issues found.
#
# Checking reply-to chain of Conversation 440030904.40936.40936
# No issues found.
#
# Checking reply-to chain of Conversation 202222639.14272.14272
# No issues found.
#
# Checking reply-to chain of Conversation 193718162.33.33
# No issues found.
#
# Checking reply-to chain of Conversation 194547346.9908.9908
# No issues found.
#
# Checking reply-to chain of Conversation 675192756.77379.77379
# No issues found.
#
# Checking reply-to chain of Conversation 674810679.58615.58615
# WARNING: ERROR: Missing utterance 674810679.58615.58615
# Checking reply-to chain of Conversation 686504218.30009.30009
# No issues found.
#
# Checking reply-to chain of Conversation 684364274.18531.18531
# No issues found.
#
# Checking reply-to chain of Conversation 233987995.3385.3385
# No issues found.
#
# Checking reply-to chain of Conversation 169476498.0.0
# No issues found.
#
# Checking reply-to chain of Conversation 9860404.13090.13090
# No issues found.
#
# Checking reply-to chain of Conversation 9757140.623.623
# No issues found.
#
# Checking reply-to chain of Conversation 253309610.37532.37532
# No issues found.
#
# Checking reply-to chain of Conversation 261192803.45628.45628
# No issues found.
#
# Checking reply-to chain of Conversation 19594450.664.739
# WARNING: ERROR: Missing utterance 19595631.3213.3214
# WARNING: ERROR: Missing utterance 19594450.664.739
# Checking reply-to chain of Conversation 19578978.276.276
# No issues found.
#
# Checking reply-to chain of Conversation 676816571.9546.9546
# No issues found.
#
# Checking reply-to chain of Conversation 470762719.4827.4827
# No issues found.
#
# Checking reply-to chain of Conversation 170428607.129367.129367
# No issues found.
#
# Checking reply-to chain of Conversation 171244678.187418.187418
# No issues found.
#
# Checking reply-to chain of Conversation 289947292.4473.4473
# No issues found.
#
# Checking reply-to chain of Conversation 290597204.9278.9278
# No issues found.
#
# Checking reply-to chain of Conversation 288525906.13902.13902
# No issues found.
#
# Checking reply-to chain of Conversation 241022339.122958.122958
# No issues found.
#
# Checking reply-to chain of Conversation 174716255.24308.24308
# No issues found.
#
# Checking reply-to chain of Conversation 174450961.9654.9649
# No issues found.
#
# Checking reply-to chain of Conversation 145807205.2210.2210
# No issues found.
#
# Checking reply-to chain of Conversation 77554132.18.18
# No issues found.
#
# Checking reply-to chain of Conversation 602394344.122058.122058
# No issues found.
#
# Checking reply-to chain of Conversation 598571628.115274.115274
# No issues found.
#
# Checking reply-to chain of Conversation 285666568.32074.32074
# No issues found.
#
# Checking reply-to chain of Conversation 286749102.51492.51492
# WARNING: ERROR: Missing utterance 286753340.53376.53575
# Checking reply-to chain of Conversation 309820950.149611.149611
# No issues found.
#
# Checking reply-to chain of Conversation 309739682.359.144674
# WARNING: ERROR: Missing utterance 309739682.359.144674
# Checking reply-to chain of Conversation 334523903.54266.54266
# No issues found.
#
# Checking reply-to chain of Conversation 334576042.59263.59263
# No issues found.
#
# Checking reply-to chain of Conversation 218427260.37970.37970
# WARNING: ERROR: Missing utterance 218427260.37970.37970
# Checking reply-to chain of Conversation 215274499.31655.31655
# No issues found.
#
# Checking reply-to chain of Conversation 592413174.22745.22745
# No issues found.
#
# Checking reply-to chain of Conversation 592413106.22745.22745
# No issues found.
#
# Checking reply-to chain of Conversation 309872749.134064.134064
# No issues found.
#
# Checking reply-to chain of Conversation 309799694.118610.118610
# WARNING: ERROR: Missing utterance 309799694.118610.118610
# Checking reply-to chain of Conversation 211715663.85849.85849
# No issues found.
#
# Checking reply-to chain of Conversation 211681199.79782.78051
# No issues found.
#
# Checking reply-to chain of Conversation 180775772.3392.3392
# No issues found.
#
# Checking reply-to chain of Conversation 191064576.40158.40119
# No issues found.
#
# Checking reply-to chain of Conversation 23693917.339.339
# No issues found.
#
# Checking reply-to chain of Conversation 29397466.22319.22319
# No issues found.
#
# Checking reply-to chain of Conversation 218968771.81560.81560
# No issues found.
#
# Checking reply-to chain of Conversation 332073264.46576.46576
# No issues found.
#
# Checking reply-to chain of Conversation 208579247.88911.88911
# No issues found.
#
# Checking reply-to chain of Conversation 207685040.155576.155576
# No issues found.
#
# Checking reply-to chain of Conversation 192455483.214686.214686
# No issues found.
#
# Checking reply-to chain of Conversation 192931179.197865.197865
# No issues found.
#
# Checking reply-to chain of Conversation 89284469.40985.40985
# No issues found.
#
# Checking reply-to chain of Conversation 44374263.17853.17853
# No issues found.
#
# Checking reply-to chain of Conversation 270297655.120641.120641
# No issues found.
#
# Checking reply-to chain of Conversation 269668743.30681.30681
# WARNING: ERROR: Missing utterance 269668743.30681.30681
# Checking reply-to chain of Conversation 238903069.69618.69618
# No issues found.
#
# Checking reply-to chain of Conversation 240429527.89491.89491
# No issues found.
#
# Checking reply-to chain of Conversation 363602652.744.744
# No issues found.
#
# Checking reply-to chain of Conversation 468075420.3597.3597
# No issues found.
#
# Checking reply-to chain of Conversation 609435580.13377.13377
# No issues found.
#
# Checking reply-to chain of Conversation 607585322.7490.7490
# WARNING: ERROR: Missing utterance 609169481.8280.8288
# Checking reply-to chain of Conversation 689554233.94320.94320
# No issues found.
#
# Checking reply-to chain of Conversation 655844491.77776.77776
# No issues found.
#
# Checking reply-to chain of Conversation 29448932.46437.46437
# No issues found.
#
# Checking reply-to chain of Conversation 62087429.189530.189530
# No issues found.
#
# Checking reply-to chain of Conversation 28475482.19751.19751
# No issues found.
#
# Checking reply-to chain of Conversation 25615433.40444.40444
# No issues found.
#
# Checking reply-to chain of Conversation 254828333.15390.15390
# No issues found.
#
# Checking reply-to chain of Conversation 254309326.12691.12691
# No issues found.
#
# Checking reply-to chain of Conversation 94526037.13231.13231
# No issues found.
#
# Checking reply-to chain of Conversation 95493930.36972.35968
# No issues found.
#
# Checking reply-to chain of Conversation 215856612.69355.69355
# No issues found.
#
# Checking reply-to chain of Conversation 215604360.67565.67565
# No issues found.
#
# Checking reply-to chain of Conversation 426534860.9002.9002
# No issues found.
#
# Checking reply-to chain of Conversation 459814094.2506.2506
# No issues found.
#
# Checking reply-to chain of Conversation 104703060.67.67
# No issues found.
#
# Checking reply-to chain of Conversation 113426114.252480.252480
# No issues found.
#
# Checking reply-to chain of Conversation 212048079.9900.9900
# No issues found.
#
# Checking reply-to chain of Conversation 84268831.3049.3049
# No issues found.
#
# Checking reply-to chain of Conversation 424037037.16015.16015
# No issues found.
#
# Checking reply-to chain of Conversation 35892071.2013.2013
# No issues found.
#
# Checking reply-to chain of Conversation 263081506.985.985
# No issues found.
#
# Checking reply-to chain of Conversation 424731436.16143.16143
# No issues found.
#
# Checking reply-to chain of Conversation 201376388.56.56
# No issues found.
#
# Checking reply-to chain of Conversation 207007491.3930.2866
# No issues found.
#
# Checking reply-to chain of Conversation 105017229.49238.49238
# No issues found.
#
# Checking reply-to chain of Conversation 110588596.57568.57568
# No issues found.
#
# Checking reply-to chain of Conversation 195331201.275790.275790
# No issues found.
#
# Checking reply-to chain of Conversation 222376382.62217.62217
# No issues found.
#
# Checking reply-to chain of Conversation 195151806.247913.247913
# No issues found.
#
# Checking reply-to chain of Conversation 193471563.269937.269937
# No issues found.
#
# Checking reply-to chain of Conversation 68848058.7850.7850
# No issues found.
#
# Checking reply-to chain of Conversation 67889814.5988.5988
# No issues found.
#
# Checking reply-to chain of Conversation 49399587.40739.40739
# No issues found.
#
# Checking reply-to chain of Conversation 50598973.66267.66240
# No issues found.
#
# Checking reply-to chain of Conversation 210315902.125007.125007
# No issues found.
#
# Checking reply-to chain of Conversation 202159598.118901.118901
# No issues found.
#
# Checking reply-to chain of Conversation 103271295.478.478
# WARNING: ERROR: Missing utterance 103271295.478.478
# Checking reply-to chain of Conversation 475182390.9864.9864
# No issues found.
#
# Checking reply-to chain of Conversation 567302410.107325.107325
# No issues found.
#
# Checking reply-to chain of Conversation 616262536.309119.309119
# No issues found.
#
# Checking reply-to chain of Conversation 479259231.189468.189299
# No issues found.
#
# Checking reply-to chain of Conversation 478585235.181902.181902
# No issues found.
#
# Checking reply-to chain of Conversation 339476612.25907.25907
# No issues found.
#
# Checking reply-to chain of Conversation 344378989.37035.37035
# No issues found.
#
# Checking reply-to chain of Conversation 39197306.101861.101861
# No issues found.
#
# Checking reply-to chain of Conversation 14524922.81579.81579
# No issues found.
#
# Checking reply-to chain of Conversation 698697194.15286.15286
# No issues found.
#
# Checking reply-to chain of Conversation 726426084.22655.22655
# WARNING: ERROR: Missing utterance 726426084.22655.22655
# Checking reply-to chain of Conversation 842659137.32798.32798
# No issues found.
#
# Checking reply-to chain of Conversation 816137520.17124.17124
# No issues found.
#
# Checking reply-to chain of Conversation 19032039.27399.27399
# No issues found.
#
# Checking reply-to chain of Conversation 13690319.3754.3754
# No issues found.
#
# Checking reply-to chain of Conversation 331876644.18982.18982
# No issues found.
#
# Checking reply-to chain of Conversation 60181816.11206.11206
# No issues found.
#
# Checking reply-to chain of Conversation 89394725.48224.48224
# No issues found.
#
# Checking reply-to chain of Conversation 34667822.5116.5116
# No issues found.
#
# Checking reply-to chain of Conversation 171900381.236075.236075
# No issues found.
#
# Checking reply-to chain of Conversation 186677272.300752.300752
# WARNING: ERROR: Missing utterance 186919619.316139.316176
# Checking reply-to chain of Conversation 217350683.16260.16260
# No issues found.
#
# Checking reply-to chain of Conversation 221089227.41173.41173
# No issues found.
#
# Checking reply-to chain of Conversation 45169947.10833.10833
# No issues found.
#
# Checking reply-to chain of Conversation 45175384.12325.12325
# No issues found.
#
# Checking reply-to chain of Conversation 701210.5465.5465
# No issues found.
#
# Checking reply-to chain of Conversation 698184.0.0
# No issues found.
#
# Checking reply-to chain of Conversation 232272868.55960.55960
# WARNING: ERROR: Missing utterance 232272868.55960.55960
# Checking reply-to chain of Conversation 214119000.30014.30014
# No issues found.
#
# Checking reply-to chain of Conversation 756315529.4224.4224
# WARNING: ERROR: Missing utterance 756315529.4243.4242
# Checking reply-to chain of Conversation 756493076.13033.13033
# No issues found.
#
# Checking reply-to chain of Conversation 444647453.3825.3825
# WARNING: ERROR: Missing utterance 444647453.3825.3825
# Checking reply-to chain of Conversation 444777645.8376.8376
# No issues found.
#
# Checking reply-to chain of Conversation 603018355.15987.15987
# No issues found.
#
# Checking reply-to chain of Conversation 501486186.1967.1967
# No issues found.
#
# Checking reply-to chain of Conversation 330717204.32361.32361
# No issues found.
#
# Checking reply-to chain of Conversation 330602562.29460.29460
# No issues found.
#
# Checking reply-to chain of Conversation 3456847.14695.14695
# No issues found.
#
# Checking reply-to chain of Conversation 59296194.7944.7944
# No issues found.
#
# Checking reply-to chain of Conversation 729791.1383.1383
# No issues found.
#
# Checking reply-to chain of Conversation 549273.0.0
# No issues found.
#
# Checking reply-to chain of Conversation 19686458.54833.54261
# No issues found.
#
# Checking reply-to chain of Conversation 21964369.77012.77012
# No issues found.
#
# Checking reply-to chain of Conversation 804776348.19564.19564
# No issues found.
#
# Checking reply-to chain of Conversation 28668126.1829.1829
# No issues found.
#
# Checking reply-to chain of Conversation 327444640.22172.22172
# No issues found.
#
# Checking reply-to chain of Conversation 482455532.2898.2898
# No issues found.
#
# Checking reply-to chain of Conversation 24597591.4316.4316
# No issues found.
#
# Checking reply-to chain of Conversation 110247180.25620.25620
# No issues found.
#
# Checking reply-to chain of Conversation 830188775.8261.8261
# No issues found.
#
# Checking reply-to chain of Conversation 830929592.45832.45499
# No issues found.
#
# Checking reply-to chain of Conversation 23947356.23566.23519
# No issues found.
#
# Checking reply-to chain of Conversation 18349485.5104.5104
# No issues found.
#
# Checking reply-to chain of Conversation 318316553.37084.37084
# No issues found.
#
# Checking reply-to chain of Conversation 323707036.42268.42268
# No issues found.
#
# Checking reply-to chain of Conversation 209226262.83702.83702
# No issues found.
#
# Checking reply-to chain of Conversation 209307971.88363.88363
# No issues found.
#
# Checking reply-to chain of Conversation 505968646.95374.95374
# No issues found.
#
# Checking reply-to chain of Conversation 496885156.90905.90905
# No issues found.
#
# Checking reply-to chain of Conversation 15594102.210385.210385
# WARNING: ERROR: Missing utterance 15594102.211153.211157
# WARNING: ERROR: Missing utterance 15594102.210385.210385
# Checking reply-to chain of Conversation 15487554.166874.167799
# WARNING: ERROR: Missing utterance 15487554.166874.167799
# Checking reply-to chain of Conversation 120995731.84245.84245
# No issues found.
#
# Checking reply-to chain of Conversation 131587481.4133.4133
# No issues found.
#
# Checking reply-to chain of Conversation 175771808.17092.17092
# No issues found.
#
# Checking reply-to chain of Conversation 173820776.10670.10670
# No issues found.
#
# Checking reply-to chain of Conversation 43634225.34656.34656
# No issues found.
#
# Checking reply-to chain of Conversation 81665442.41639.41639
# No issues found.
#
# Checking reply-to chain of Conversation 114814137.19490.19490
# No issues found.
#
# Checking reply-to chain of Conversation 118510990.35344.35344
# No issues found.
#
# Checking reply-to chain of Conversation 679176527.69481.69481
# No issues found.
#
# Checking reply-to chain of Conversation 677525916.58816.58816
# No issues found.
#
# Checking reply-to chain of Conversation 450348101.1178.1178
# No issues found.
#
# Checking reply-to chain of Conversation 433172304.25123.28457
# WARNING: ERROR: Missing utterance 433172304.25123.28457
# Checking reply-to chain of Conversation 206818187.39556.39556
# No issues found.
#
# Checking reply-to chain of Conversation 209354994.48068.48068
# No issues found.
#
# Checking reply-to chain of Conversation 304172801.16750.16750
# No issues found.
#
# Checking reply-to chain of Conversation 335963042.17736.17736
# WARNING: ERROR: Missing utterance 335963042.17736.17736
# WARNING: ERROR: Missing utterance 335963042.18592.18337
# Checking reply-to chain of Conversation 41991382.52805.52805
# No issues found.
#
# Checking reply-to chain of Conversation 42039324.52494.52494
# No issues found.
#
# Checking reply-to chain of Conversation 343425520.1149.1149
# No issues found.
#
# Checking reply-to chain of Conversation 225085913.54.54
# No issues found.
#
# Checking reply-to chain of Conversation 28576936.251426.251426
# No issues found.
#
# Checking reply-to chain of Conversation 36609241.140684.140684
# No issues found.
#
# Checking reply-to chain of Conversation 79184445.17659.17659
# No issues found.
#
# Checking reply-to chain of Conversation 130406990.30183.30183
# No issues found.
#
# Checking reply-to chain of Conversation 288471421.7538.7538
# No issues found.
#
# Checking reply-to chain of Conversation 308212225.20117.20117
# No issues found.
#
# Checking reply-to chain of Conversation 419167397.8810.8810
# No issues found.
#
# Checking reply-to chain of Conversation 431855130.18319.18319
# No issues found.
#
# Checking reply-to chain of Conversation 119611018.34356.34356
# No issues found.
#
# Checking reply-to chain of Conversation 119741303.36118.36118
# No issues found.
#
# Checking reply-to chain of Conversation 12555849.247.247
# No issues found.
#
# Checking reply-to chain of Conversation 12557316.3558.3558
# WARNING: ERROR: Missing utterance 12557316.3558.3558
# Checking reply-to chain of Conversation 33239804.93286.93286
# No issues found.
#
# Checking reply-to chain of Conversation 32038624.63259.63259
# No issues found.
#
# Checking reply-to chain of Conversation 123376712.21847.21847
# No issues found.
#
# Checking reply-to chain of Conversation 132071812.26313.26313
# No issues found.
#
# Checking reply-to chain of Conversation 545795998.5792.5792
# No issues found.
#
# Checking reply-to chain of Conversation 566377175.5641.5641
# No issues found.
#
# Checking reply-to chain of Conversation 571451725.13073.13073
# No issues found.
#
# Checking reply-to chain of Conversation 551192922.8298.8298
# No issues found.
#
# Checking reply-to chain of Conversation 219684079.236.0
# No issues found.
#
# Checking reply-to chain of Conversation 219684079.749.0
# No issues found.
#
# Checking reply-to chain of Conversation 744911048.74260.74260
# No issues found.
#
# Checking reply-to chain of Conversation 746227036.84017.83951
# No issues found.
#
# Checking reply-to chain of Conversation 735662847.63971.63971
# No issues found.
#
# Checking reply-to chain of Conversation 744447526.62089.62089
# No issues found.
#
# Checking reply-to chain of Conversation 724541734.46170.46170
# No issues found.
#
# Checking reply-to chain of Conversation 714183141.20530.20530
# No issues found.
#
# Checking reply-to chain of Conversation 274927784.32062.32062
# No issues found.
#
# Checking reply-to chain of Conversation 273791406.26159.26159
# No issues found.
#
# Checking reply-to chain of Conversation 377377077.174238.174238
# No issues found.
#
# Checking reply-to chain of Conversation 376899200.195550.195550
# No issues found.
#
# Checking reply-to chain of Conversation 354488901.139567.139567
# No issues found.
#
# Checking reply-to chain of Conversation 357158057.152895.152895
# No issues found.
#
# Checking reply-to chain of Conversation 304247607.4194.4194
# No issues found.
#
# Checking reply-to chain of Conversation 303974195.20.20
# No issues found.
#
# Checking reply-to chain of Conversation 629393677.37752.37752
# No issues found.
#
# Checking reply-to chain of Conversation 307307626.5085.5085
# No issues found.
#
# Checking reply-to chain of Conversation 363001793.73066.73066
# No issues found.
#
# Checking reply-to chain of Conversation 160894688.45391.45391
# No issues found.
#
# Checking reply-to chain of Conversation 167881263.32390.32390
# No issues found.
#
# Checking reply-to chain of Conversation 29345353.3164.3164
# No issues found.
#
# Checking reply-to chain of Conversation 669851834.60900.60900
# No issues found.
#
# Checking reply-to chain of Conversation 412404062.29625.29625
# No issues found.
#
# Checking reply-to chain of Conversation 227155426.94550.94550
# No issues found.
#
# Checking reply-to chain of Conversation 225044163.103145.103145
# No issues found.
#
# Checking reply-to chain of Conversation 8466322.3086.3086
# No issues found.
#
# Checking reply-to chain of Conversation 236412028.27985.27985
# No issues found.
#
# Checking reply-to chain of Conversation 36177740.22903.22903
# No issues found.
#
# Checking reply-to chain of Conversation 30546967.19522.19522
# No issues found.
#
# Checking reply-to chain of Conversation 39687849.1257.1257
# No issues found.
#
# Checking reply-to chain of Conversation 35935693.0.0
# WARNING: ERROR: Missing utterance 35935693.0.0
# Checking reply-to chain of Conversation 367283956.7229.7229
# No issues found.
#
# Checking reply-to chain of Conversation 359613718.211156.211156
# No issues found.
#
# Checking reply-to chain of Conversation 651493864.7775.7775
# No issues found.
#
# Checking reply-to chain of Conversation 650023950.1830.1830
# WARNING: ERROR: Missing utterance 650537743.4732.4759
# Checking reply-to chain of Conversation 674557453.15271.15271
# No issues found.
#
# Checking reply-to chain of Conversation 654609565.110501.110501
# No issues found.
#
# Checking reply-to chain of Conversation 696399024.14914.14914
# WARNING: ERROR: Missing utterance 696399024.14914.14914
# Checking reply-to chain of Conversation 696268831.3111.3111
# No issues found.
#
# Checking reply-to chain of Conversation 656446214.15024.15024
# No issues found.
#
# Checking reply-to chain of Conversation 645324539.8059.8059
# No issues found.
#
# Checking reply-to chain of Conversation 298632259.93220.93220
# No issues found.
#
# Checking reply-to chain of Conversation 275528681.90230.90230
# No issues found.
#
# Checking reply-to chain of Conversation 144527977.38033.38186
# No issues found.
#
# Checking reply-to chain of Conversation 130103164.11480.11480
# No issues found.
#
# Checking reply-to chain of Conversation 136839942.5545.5545
# No issues found.
#
# Checking reply-to chain of Conversation 59785793.2782.2782
# No issues found.
#
# Checking reply-to chain of Conversation 285576876.11141.11086
# No issues found.
#
# Checking reply-to chain of Conversation 276381374.499.499
# No issues found.
#
# Checking reply-to chain of Conversation 157042390.2110.1797
# No issues found.
#
# Checking reply-to chain of Conversation 224075029.12039.12039
# WARNING: ERROR: Missing utterance 231505841.13881.13880
# Checking reply-to chain of Conversation 205490775.575.575
# No issues found.
#
# Checking reply-to chain of Conversation 206131755.2354.2348
# No issues found.
#
# Checking reply-to chain of Conversation 235877654.87437.87437
# No issues found.
#
# Checking reply-to chain of Conversation 235788517.66804.66804
# No issues found.
#
# Checking reply-to chain of Conversation 602651222.444.444
# WARNING: ERROR: Missing utterance 602651222.444.444
# WARNING: ERROR: Missing utterance 727111898.2206.2206
# Checking reply-to chain of Conversation 576608702.45539.45539
# WARNING: ERROR: Missing utterance 576608702.45539.45539
# Checking reply-to chain of Conversation 338154888.43414.43414
# No issues found.
#
# Checking reply-to chain of Conversation 338108555.41642.41642
# No issues found.
#
# Checking reply-to chain of Conversation 407520161.10904.10904
# No issues found.
#
# Checking reply-to chain of Conversation 407455278.10400.10400
# No issues found.
#
# Checking reply-to chain of Conversation 38591519.50243.50547
# WARNING: ERROR: Missing utterance 38975184.57757.57757
# WARNING: ERROR: Missing utterance 38957562.55463.55463
# WARNING: ERROR: Missing utterance 38591519.50910.51223
# Checking reply-to chain of Conversation 37393102.36612.36612
# No issues found.
#
# Checking reply-to chain of Conversation 86684421.53709.53709
# No issues found.
#
# Checking reply-to chain of Conversation 113531759.13528.13528
# No issues found.
#
# Checking reply-to chain of Conversation 36302778.10910.10910
# No issues found.
#
# Checking reply-to chain of Conversation 74025127.19611.19611
# No issues found.
#
# Checking reply-to chain of Conversation 181655527.1162.1162
# No issues found.
#
# Checking reply-to chain of Conversation 168994629.118480.118480
# No issues found.
#
# Checking reply-to chain of Conversation 178727199.30516.30516
# No issues found.
#
# Checking reply-to chain of Conversation 105348748.104.104
# WARNING: ERROR: Missing utterance 105348748.104.104
# Checking reply-to chain of Conversation 303868524.4308.4308
# No issues found.
#
# Checking reply-to chain of Conversation 117911384.5410.489
# No issues found.
#
# Checking reply-to chain of Conversation 753001241.27091.27091
# No issues found.
#
# Checking reply-to chain of Conversation 747898447.9638.9638
# No issues found.
#
# Checking reply-to chain of Conversation 122434890.15100.15100
# No issues found.
#
# Checking reply-to chain of Conversation 47645114.13406.13406
# No issues found.
#
# Checking reply-to chain of Conversation 386372872.49161.49161
# No issues found.
#
# Checking reply-to chain of Conversation 373792456.33229.33229
# No issues found.
#
# Checking reply-to chain of Conversation 192413701.64524.64524
# WARNING: ERROR: Missing utterance 192413701.64524.64524
# Checking reply-to chain of Conversation 133146249.34053.34053
# No issues found.
#
# Checking reply-to chain of Conversation 131348475.17100.17100
# No issues found.
#
# Checking reply-to chain of Conversation 31910797.115.115
# No issues found.
#
# Checking reply-to chain of Conversation 223685157.63098.59911
# No issues found.
#
# Checking reply-to chain of Conversation 223661583.55739.55739
# No issues found.
#
# Checking reply-to chain of Conversation 623261343.139532.139532
# No issues found.
#
# Checking reply-to chain of Conversation 600023446.63480.63480
# No issues found.
#
# Checking reply-to chain of Conversation 110260019.134313.134313
# No issues found.
#
# Checking reply-to chain of Conversation 717081779.107455.107455
# No issues found.
#
# Checking reply-to chain of Conversation 52680746.95773.95773
# No issues found.
#
# Checking reply-to chain of Conversation 24118781.37.37
# WARNING: ERROR: Missing utterance 24118781.37.37
# Checking reply-to chain of Conversation 229002613.333487.333487
# No issues found.
#
# Checking reply-to chain of Conversation 229148223.340925.339631
# No issues found.
#
# Checking reply-to chain of Conversation 580068105.84110.84110
# No issues found.
#
# Checking reply-to chain of Conversation 581781813.726.726
# No issues found.
#
# Checking reply-to chain of Conversation 500307886.31909.31909
# No issues found.
#
# Checking reply-to chain of Conversation 466079646.23058.23058
# No issues found.
#
# Checking reply-to chain of Conversation 747294667.32175.32175
# No issues found.
#
# Checking reply-to chain of Conversation 743766825.32111.32111
# No issues found.
#
# Checking reply-to chain of Conversation 222987629.624410.624410
# No issues found.
#
# Checking reply-to chain of Conversation 220873646.265567.259050
# No issues found.
#
# Checking reply-to chain of Conversation 626028390.17390.17390
# No issues found.
#
# Checking reply-to chain of Conversation 637956280.2202.2202
# No issues found.
#
# Checking reply-to chain of Conversation 822299164.18691.18691
# No issues found.
#
# Checking reply-to chain of Conversation 797357251.5721.5721
# No issues found.
#
# Checking reply-to chain of Conversation 269794336.41085.41085
# No issues found.
#
# Checking reply-to chain of Conversation 269156482.14986.14986
# No issues found.
#
# Checking reply-to chain of Conversation 428514403.4963.4963
# No issues found.
#
# Checking reply-to chain of Conversation 451125006.7146.7145
# No issues found.
#
# Checking reply-to chain of Conversation 107596212.39648.39648
# No issues found.
#
# Checking reply-to chain of Conversation 107505434.38942.38979
# No issues found.
#
# Checking reply-to chain of Conversation 83333257.11670.11670
# No issues found.
#
# Checking reply-to chain of Conversation 80314291.5767.5767
# No issues found.
#
# Checking reply-to chain of Conversation 801617686.26539.26539
# No issues found.
#
# Checking reply-to chain of Conversation 825035164.30719.30719
# No issues found.
#
# Checking reply-to chain of Conversation 291753275.17528.19444
# WARNING: ERROR: Missing utterance 291753275.17528.19444
# Checking reply-to chain of Conversation 291678883.44803.44803
# No issues found.
#
# Checking reply-to chain of Conversation 676160758.62395.62395
# No issues found.
#
# Checking reply-to chain of Conversation 674966432.9607.9607
# WARNING: ERROR: Missing utterance 675692003.24609.24610
# Checking reply-to chain of Conversation 5066581.23893.23821
# No issues found.
#
# Checking reply-to chain of Conversation 5009702.20355.20355
# No issues found.
#
# Checking reply-to chain of Conversation 258462087.78844.78601
# No issues found.
#
# Checking reply-to chain of Conversation 257090205.52361.52019
# No issues found.
#
# Checking reply-to chain of Conversation 243072242.56485.56485
# No issues found.
#
# Checking reply-to chain of Conversation 231029409.12673.12673
# No issues found.
#
# Checking reply-to chain of Conversation 237818046.140687.140687
# No issues found.
#
# Checking reply-to chain of Conversation 226406744.123089.123089
# No issues found.
#
# Checking reply-to chain of Conversation 106720504.622.622
# No issues found.
#
# Checking reply-to chain of Conversation 104266040.31698.31698
# No issues found.
#
# Checking reply-to chain of Conversation 58835577.90595.90595
# No issues found.
#
# Checking reply-to chain of Conversation 59172979.120711.120711
# No issues found.
#
# Checking reply-to chain of Conversation 40662735.38216.43739
# No issues found.
#
# Checking reply-to chain of Conversation 30121908.22504.22504
# No issues found.
#
# Checking reply-to chain of Conversation 574785566.39590.39590
# No issues found.
#
# Checking reply-to chain of Conversation 494489047.18738.18738
# No issues found.
#
# Checking reply-to chain of Conversation 65917034.76917.76917
# No issues found.
#
# Checking reply-to chain of Conversation 60115345.1603.1603
# No issues found.
#
# Checking reply-to chain of Conversation 393246590.3402.3402
# No issues found.
#
# Checking reply-to chain of Conversation 257727392.0.0
# No issues found.
#
# Checking reply-to chain of Conversation 19703427.11295.11295
# No issues found.
#
# Checking reply-to chain of Conversation 17742281.3575.3575
# No issues found.
#
# Checking reply-to chain of Conversation 73758383.55559.55559
# No issues found.
#
# Checking reply-to chain of Conversation 73716390.46468.46468
# No issues found.
#
# Checking reply-to chain of Conversation 220175152.10712.10712
# No issues found.
#
# Checking reply-to chain of Conversation 246179143.18146.18146
# No issues found.
#
# Checking reply-to chain of Conversation 835398293.25779.25779
# No issues found.
#
# Checking reply-to chain of Conversation 798965834.19096.19096
# No issues found.
#
# Checking reply-to chain of Conversation 340645802.66041.66041
# No issues found.
#
# Checking reply-to chain of Conversation 323121231.41167.41167
# No issues found.
#
# Checking reply-to chain of Conversation 83677906.66335.66335
# WARNING: ERROR: Missing utterance 83677906.66335.66335
# Checking reply-to chain of Conversation 81249092.39456.39456
# No issues found.
#
# Checking reply-to chain of Conversation 120755140.59696.58124
# WARNING: ERROR: Missing utterance 123203450.9080.9082
# Checking reply-to chain of Conversation 121446655.65178.65178
# No issues found.
#
# Checking reply-to chain of Conversation 313653896.28410.28410
# No issues found.
#
# Checking reply-to chain of Conversation 277541613.24558.24558
# No issues found.
#
# Checking reply-to chain of Conversation 764854379.45195.45195
# No issues found.
#
# Checking reply-to chain of Conversation 763150290.17662.17662
# No issues found.
#
# Checking reply-to chain of Conversation 464271325.253613.253613
# No issues found.
#
# Checking reply-to chain of Conversation 464097540.209570.209570
# No issues found.
#
# Checking reply-to chain of Conversation 63510424.147201.147201
# No issues found.
#
# Checking reply-to chain of Conversation 63375088.121993.121993
# No issues found.
#
# Checking reply-to chain of Conversation 6626691.15141.15141
# No issues found.
#
# Checking reply-to chain of Conversation 2586406.3018.3013
# No issues found.
#
# Checking reply-to chain of Conversation 493067775.23733.23733
# No issues found.
#
# Checking reply-to chain of Conversation 486028725.19066.19066
# No issues found.
#
# Checking reply-to chain of Conversation 489397642.53202.53202
# No issues found.
#
# Checking reply-to chain of Conversation 489382220.43899.43899
# WARNING: ERROR: Missing utterance 489382220.43899.43899
# Checking reply-to chain of Conversation 460542282.67292.67292
# No issues found.
#
# Checking reply-to chain of Conversation 458313117.27986.27986
# No issues found.
#
# Checking reply-to chain of Conversation 810726841.14151.14151
# No issues found.
#
# Checking reply-to chain of Conversation 805897326.21785.21785
# No issues found.
#
# Checking reply-to chain of Conversation 673639649.813.813
# No issues found.
#
# Checking reply-to chain of Conversation 81213427.6924.6924
# No issues found.
#
# Checking reply-to chain of Conversation 84937827.119428.119428
# No issues found.
#
# Checking reply-to chain of Conversation 82097839.59009.59009
# No issues found.
#
# Checking reply-to chain of Conversation 835374269.17465.17465
# No issues found.
#
# Checking reply-to chain of Conversation 477506225.5194.5194
# No issues found.
#
# Checking reply-to chain of Conversation 578859686.3520.3520
# No issues found.
#
# Checking reply-to chain of Conversation 602392649.17217.17217
# No issues found.
#
# Checking reply-to chain of Conversation 523088517.86277.86277
# No issues found.
#
# Checking reply-to chain of Conversation 539562517.94583.94583
# WARNING: ERROR: Missing utterance 539562517.94583.94583
# Checking reply-to chain of Conversation 511824424.36946.36946
# No issues found.
#
# Checking reply-to chain of Conversation 512463071.61606.61606
# No issues found.
#
# Checking reply-to chain of Conversation 601192270.29413.29353
# WARNING: ERROR: Missing utterance 601432916.31124.39173
# Checking reply-to chain of Conversation 601204270.35532.35524
# WARNING: ERROR: Missing utterance 601204270.35532.35524
# Checking reply-to chain of Conversation 155919329.61331.61331
# No issues found.
#
# Checking reply-to chain of Conversation 163311269.81491.81491
# No issues found.
#
# Checking reply-to chain of Conversation 177549154.47626.47626
# No issues found.
#
# Checking reply-to chain of Conversation 177487987.39117.39117
# No issues found.
#
# Checking reply-to chain of Conversation 21968107.6026.6026
# No issues found.
#
# Checking reply-to chain of Conversation 46029614.19522.19522
# No issues found.
#
# Checking reply-to chain of Conversation 106255236.25874.25874
# No issues found.
#
# Checking reply-to chain of Conversation 80492594.5950.5950
# No issues found.
#
# Checking reply-to chain of Conversation 725906091.196990.196990
# No issues found.
#
# Checking reply-to chain of Conversation 725874736.171752.171752
# No issues found.
#
# Checking reply-to chain of Conversation 273630609.83017.83017
# No issues found.
#
# Checking reply-to chain of Conversation 272521689.58179.58179
# No issues found.
#
# Checking reply-to chain of Conversation 684024919.10307.10307
# No issues found.
#
# Checking reply-to chain of Conversation 684638610.9425.9425
# No issues found.
#
# Checking reply-to chain of Conversation 273826842.133960.133960
# No issues found.
#
# Checking reply-to chain of Conversation 273484825.113387.113387
# No issues found.
#
# Checking reply-to chain of Conversation 6464605.35747.35747
# No issues found.
#
# Checking reply-to chain of Conversation 6842916.53254.53254
# No issues found.
#
# Checking reply-to chain of Conversation 19343936.125194.125194
# No issues found.
#
# Checking reply-to chain of Conversation 132906053.51831.51822
# No issues found.
#
# Checking reply-to chain of Conversation 19142390.163.163
# No issues found.
#
# Checking reply-to chain of Conversation 18986611.104587.104587
# No issues found.
#
# Checking reply-to chain of Conversation 26358264.26916.26916
# No issues found.
#
# Checking reply-to chain of Conversation 28692327.69932.69932
# No issues found.
#
# Checking reply-to chain of Conversation 685051058.91906.91906
# No issues found.
#
# Checking reply-to chain of Conversation 706212519.128.128
# No issues found.
#
# Checking reply-to chain of Conversation 13753778.60887.60887
# No issues found.
#
# Checking reply-to chain of Conversation 12084656.55779.55779
# No issues found.
#
# Checking reply-to chain of Conversation 708269559.92828.92828
# No issues found.
#
# Checking reply-to chain of Conversation 707749490.65542.65542
# No issues found.
#
# Checking reply-to chain of Conversation 62396724.47175.47175
# No issues found.
#
# Checking reply-to chain of Conversation 62380614.44707.44707
# No issues found.
#
# Checking reply-to chain of Conversation 22614773.1438.1438
# No issues found.
#
# Checking reply-to chain of Conversation 32650250.3724.3724
# WARNING: ERROR: Missing utterance 33033868.5566.5601
# Checking reply-to chain of Conversation 232250517.22904.22904
# No issues found.
#
# Checking reply-to chain of Conversation 228499882.44489.44491
# No issues found.
#
# Checking reply-to chain of Conversation 438110825.89927.89927
# No issues found.
#
# Checking reply-to chain of Conversation 437976342.73643.73643
# No issues found.
#
# Checking reply-to chain of Conversation 688274527.24508.24508
# No issues found.
#
# Checking reply-to chain of Conversation 616866220.7157.7157
# No issues found.
#
# Checking reply-to chain of Conversation 13521263.3340.3340
# No issues found.
#
# Checking reply-to chain of Conversation 57536037.15804.15804
# No issues found.
#
# Checking reply-to chain of Conversation 428948370.54430.54430
# No issues found.
#
# Checking reply-to chain of Conversation 428707734.52277.52277
# No issues found.
#
# Checking reply-to chain of Conversation 393973338.36183.36183
# No issues found.
#
# Checking reply-to chain of Conversation 373564042.28753.28753
# No issues found.
#
# Checking reply-to chain of Conversation 495435334.22332.22326
# No issues found.
#
# Checking reply-to chain of Conversation 495894607.41404.41404
# No issues found.
#
# ...
# No issues found.
#
# Checking reply-to chain of Conversation 200383489.25610.25610
# No issues found.
#
# Checking reply-to chain of Conversation 51620047.7258.7258
# No issues found.
#
# Checking reply-to chain of Conversation 9969444.2252.2252
# No issues found.
#
# Checking reply-to chain of Conversation 223421212.27929.27929
# No issues found.
#
# Checking reply-to chain of Conversation 155236304.10904.11114
# No issues found.
#
# Checking reply-to chain of Conversation 17873587.67449.67449
# No issues found.
#
# Checking reply-to chain of Conversation 17826923.218935.218935
# No issues found.
#
# Checking reply-to chain of Conversation 78821833.122959.122959
# No issues found.
#
# Checking reply-to chain of Conversation 79063372.132281.132281
# No issues found.
#
# Checking reply-to chain of Conversation 563196185.83967.83967
# No issues found.
#
# Checking reply-to chain of Conversation 587216034.136883.136883
# No issues found.
#
# Checking reply-to chain of Conversation 184636850.204870.204870
# No issues found.
#
# Checking reply-to chain of Conversation 118619412.30891.30891
# No issues found.
#
# Checking reply-to chain of Conversation 75526612.172400.172400
# No issues found.
#
# Checking reply-to chain of Conversation 74222555.164316.164316
# No issues found.
#
# Checking reply-to chain of Conversation 143922570.32344.32344
# No issues found.
#
# Checking reply-to chain of Conversation 181926165.52828.52828
# No issues found.
#
# Checking reply-to chain of Conversation 98557146.17700.0
# No issues found.
#
# Checking reply-to chain of Conversation 107493556.40549.40549
# No issues found.
#
# Checking reply-to chain of Conversation 372573469.127605.127605
# No issues found.
#
# Checking reply-to chain of Conversation 340650593.117553.117553
# No issues found.
#
# Checking reply-to chain of Conversation 222243880.23118.23118
# No issues found.
#
# Checking reply-to chain of Conversation 220072266.15225.15225
# No issues found.
#
# Checking reply-to chain of Conversation 78208704.11589.11589
# No issues found.
#
# Checking reply-to chain of Conversation 25187470.1274.1274
# WARNING: ERROR: Missing utterance 25187470.1274.1274
# Checking reply-to chain of Conversation 56903840.7542.7542
# WARNING: ERROR: Missing utterance 56903840.7542.7542
# Checking reply-to chain of Conversation 11454508.2556.2556
# No issues found.
#
# Checking reply-to chain of Conversation 747897051.86355.86355
# No issues found.
#
# Checking reply-to chain of Conversation 611533451.48985.48985
# No issues found.
#
# Checking reply-to chain of Conversation 131397810.13228.13228
# No issues found.
#
# Checking reply-to chain of Conversation 206196220.51918.51918
# No issues found.
#
# Checking reply-to chain of Conversation 47334370.196284.196284
# No issues found.
#
# Checking reply-to chain of Conversation 47566699.229005.229005
# No issues found.
#
# Checking reply-to chain of Conversation 334776438.27739.27739
# No issues found.
#
# Checking reply-to chain of Conversation 307409332.116582.116582
# WARNING: ERROR: Missing utterance 307411795.120437.120450
# WARNING: ERROR: Missing utterance 307411795.121285.121301
# Checking reply-to chain of Conversation 623785425.41941.40874
# WARNING: ERROR: Missing utterance 624571835.42489.45456
# Checking reply-to chain of Conversation 624721061.49980.49747
# No issues found.
#
# Checking reply-to chain of Conversation 245458714.96186.96186
# No issues found.
#
# Checking reply-to chain of Conversation 245262803.90271.90271
# No issues found.
#
# Checking reply-to chain of Conversation 207319117.47094.47094
# No issues found.
#
# Checking reply-to chain of Conversation 35659323.6895.6895
# No issues found.
#
# Checking reply-to chain of Conversation 36268090.17743.17743
# No issues found.
#
# Checking reply-to chain of Conversation 36513759.34655.34655
# No issues found.
#
# Checking reply-to chain of Conversation 123858261.57301.52065
# No issues found.
#
# Checking reply-to chain of Conversation 115118716.11604.11604
# No issues found.
#
# Checking reply-to chain of Conversation 85944267.24031.24031
# No issues found.
#
# Checking reply-to chain of Conversation 85432439.7043.7043
# No issues found.
#
# Checking reply-to chain of Conversation 148898478.6485.6485
# No issues found.
#
# Checking reply-to chain of Conversation 143409377.102778.102778
# No issues found.
#
# Checking reply-to chain of Conversation 708472694.66370.66370
# No issues found.
#
# Checking reply-to chain of Conversation 708306001.59096.59096
# No issues found.
#
# Checking reply-to chain of Conversation 513270650.28217.28217
# No issues found.
#
# Checking reply-to chain of Conversation 513013737.27053.27053
# No issues found.
#
# Checking reply-to chain of Conversation 478709361.27519.27519
# No issues found.
#
# Checking reply-to chain of Conversation 478564053.25960.25960
# No issues found.
#
# Checking reply-to chain of Conversation 335010500.573223.566159
# WARNING: ERROR: Missing utterance 335010500.573223.566159
# Checking reply-to chain of Conversation 335037420.597150.597150
# No issues found.
#
# Checking reply-to chain of Conversation 333679737.393932.393932
# No issues found.
#
# Checking reply-to chain of Conversation 333681678.395819.395767
# No issues found.
#
# Checking reply-to chain of Conversation 285124538.61515.61515
# No issues found.
#
# Checking reply-to chain of Conversation 285102889.58627.58627
# No issues found.
#
# Checking reply-to chain of Conversation 280499001.87002.87002
# No issues found.
#
# Checking reply-to chain of Conversation 280240039.94770.94770
# No issues found.
#
# Checking reply-to chain of Conversation 224597043.604665.604665
# No issues found.
#
# Checking reply-to chain of Conversation 224521275.632426.632426
# No issues found.
#
# Checking reply-to chain of Conversation 187592276.109067.111222
# WARNING: ERROR: Missing utterance 187592276.109067.111222
# Checking reply-to chain of Conversation 187327169.111083.111083
# No issues found.
#
# Checking reply-to chain of Conversation 43247243.3401.3401
# No issues found.
#
# Checking reply-to chain of Conversation 13821842.111.111
# No issues found.
#
# Checking reply-to chain of Conversation 141735464.188270.188270
# No issues found.
#
# Checking reply-to chain of Conversation 141723629.182313.182313
# No issues found.
#
# Checking reply-to chain of Conversation 87330700.32278.32278
# No issues found.
#
# Checking reply-to chain of Conversation 87289274.12860.12860
# No issues found.
#
# Checking reply-to chain of Conversation 215630746.123524.123524
# No issues found.
#
# Checking reply-to chain of Conversation 97736747.26897.26897
# No issues found.
#
# Checking reply-to chain of Conversation 181451254.36.36
# No issues found.
#
# Checking reply-to chain of Conversation 182614870.5054.5054
# No issues found.
#
# Checking reply-to chain of Conversation 647093870.4991.4991
# No issues found.
#
# Checking reply-to chain of Conversation 649045909.9623.9623
# No issues found.
#
# Checking reply-to chain of Conversation 563173032.84104.84104
# No issues found.
#
# Checking reply-to chain of Conversation 550911154.2522.23642
# WARNING: ERROR: Missing utterance 550911154.2522.23642
# Checking reply-to chain of Conversation 23238386.21186.21186
# No issues found.
#
# Checking reply-to chain of Conversation 50897983.70686.70686
# No issues found.
#
# Checking reply-to chain of Conversation 428066439.33001.33001
# No issues found.
#
# Checking reply-to chain of Conversation 426370947.12766.12766
# No issues found.
#
# Checking reply-to chain of Conversation 281527053.52918.52918
# No issues found.
#
# Checking reply-to chain of Conversation 279233642.65874.65874
# No issues found.
#
# Checking reply-to chain of Conversation 833385517.83369.83369
# WARNING: ERROR: Missing utterance 833385517.83369.83369
# Checking reply-to chain of Conversation 825607038.54663.54663
# No issues found.
#
# Checking reply-to chain of Conversation 422273386.111380.111380
# No issues found.
#
# Checking reply-to chain of Conversation 421687225.105034.105034
# No issues found.
#
# Checking reply-to chain of Conversation 68779044.245595.245595
# No issues found.
#
# Checking reply-to chain of Conversation 68107001.243523.243523
# No issues found.
#
# Checking reply-to chain of Conversation 134531717.53898.53898
# WARNING: ERROR: Missing utterance 134531747.53931.53931
# Checking reply-to chain of Conversation 131016367.9383.9383
# No issues found.
#
# Checking reply-to chain of Conversation 648915220.220692.220692
# No issues found.
#
# Checking reply-to chain of Conversation 646310893.197356.197356
# No issues found.
#
# Checking reply-to chain of Conversation 246544326.48318.48318
# No issues found.
#
# Checking reply-to chain of Conversation 250215222.88739.88739
# No issues found.
#
# Checking reply-to chain of Conversation 328937880.64292.64292
# No issues found.
#
# Checking reply-to chain of Conversation 328833625.31131.31131
# No issues found.
#
# Checking reply-to chain of Conversation 15216017.76147.76147
# No issues found.
#
# Checking reply-to chain of Conversation 68239781.15650.15650
# No issues found.
#
# Checking reply-to chain of Conversation 12597056.66411.66411
# No issues found.
#
# Checking reply-to chain of Conversation 13985430.44704.44704
# No issues found.
#
# Checking reply-to chain of Conversation 129847853.105738.105738
# WARNING: ERROR: Missing utterance 129847853.105738.105738
# Checking reply-to chain of Conversation 130017268.106789.106789
# No issues found.
#
# Checking reply-to chain of Conversation 73625580.40952.40952
# No issues found.
#
# Checking reply-to chain of Conversation 73079937.38503.38503
# No issues found.
#
# Checking reply-to chain of Conversation 101444035.163487.163463
# No issues found.
#
# Checking reply-to chain of Conversation 101186156.157804.157804
# No issues found.
#
# Checking reply-to chain of Conversation 5239818.17667.17667
# No issues found.
#
# Checking reply-to chain of Conversation 2042455.3730.3730
# No issues found.
#
# Checking reply-to chain of Conversation 137250282.53843.53843
# No issues found.
#
# Checking reply-to chain of Conversation 129882965.49291.49291
# No issues found.
#
# Checking reply-to chain of Conversation 296103800.162185.162185
# No issues found.
#
# Checking reply-to chain of Conversation 296383590.211149.211149
# No issues found.
#
# Checking reply-to chain of Conversation 184209031.199517.199517
# No issues found.
#
# Checking reply-to chain of Conversation 183782445.154380.154380
# No issues found.
#
# Checking reply-to chain of Conversation 773640871.23773.23773
# No issues found.
#
# Checking reply-to chain of Conversation 442279975.15309.15309
# No issues found.
#
# Checking reply-to chain of Conversation 288466917.71301.71301
# No issues found.
#
# Checking reply-to chain of Conversation 286612345.67610.67610
# No issues found.
#
# Checking reply-to chain of Conversation 487168901.23422.23422
# No issues found.
#
# Checking reply-to chain of Conversation 476864822.15197.15197
# No issues found.
#
# Checking reply-to chain of Conversation 21507950.14018.14018
# No issues found.
#
# Checking reply-to chain of Conversation 77520446.78226.78226
# No issues found.
#
# Checking reply-to chain of Conversation 130211170.71708.71708
# No issues found.
#
# Checking reply-to chain of Conversation 129049043.66422.66422
# No issues found.
#
# Checking reply-to chain of Conversation 572184332.44989.44989
# No issues found.
#
# Checking reply-to chain of Conversation 406813809.38301.38301
# No issues found.
#
# Checking reply-to chain of Conversation 32226089.34475.34475
# No issues found.
#
# Checking reply-to chain of Conversation 58059387.12350.12350
# No issues found.
#
# Checking reply-to chain of Conversation 27845708.69159.69159
# No issues found.
#
# Checking reply-to chain of Conversation 23046139.195379.195362
# No issues found.
#
# Checking reply-to chain of Conversation 581866548.2807.2807
# No issues found.
#
# Checking reply-to chain of Conversation 337846361.69.69
# No issues found.
#
# Checking reply-to chain of Conversation 26011961.18032.18032
# No issues found.
#
# Checking reply-to chain of Conversation 8847712.1899.1899
# No issues found.
#
# Checking reply-to chain of Conversation 233659167.37134.37134
# No issues found.
#
# Checking reply-to chain of Conversation 247850378.42223.42223
# No issues found.
#
# Checking reply-to chain of Conversation 226630883.3889.3889
# No issues found.
#
# Checking reply-to chain of Conversation 243059441.9698.9698
# No issues found.
#
# Checking reply-to chain of Conversation 734490676.95591.95591
# No issues found.
#
# Checking reply-to chain of Conversation 733530266.68452.58792
# No issues found.
#
# Checking reply-to chain of Conversation 730178616.16748.16748
# No issues found.
#
# Checking reply-to chain of Conversation 653143049.6324.6324
# No issues found.
#
# Checking reply-to chain of Conversation 355388338.20794.20794
# No issues found.
#
# Checking reply-to chain of Conversation 366796148.35031.35031
# No issues found.
#
# Checking reply-to chain of Conversation 113637694.52.52
# No issues found.
#
# Checking reply-to chain of Conversation 176555116.8001.8001
# No issues found.
#
# Checking reply-to chain of Conversation 221775836.39462.39462
# No issues found.
#
# Checking reply-to chain of Conversation 9400564.1694.1694
# No issues found.
#
# Checking reply-to chain of Conversation 107996234.3849.3849
# No issues found.
#
# Checking reply-to chain of Conversation 109562615.10646.10646
# No issues found.
#
# Checking reply-to chain of Conversation 529139355.15074.15074
# No issues found.
#
# Checking reply-to chain of Conversation 529156476.15474.15474
# No issues found.
#
# Checking reply-to chain of Conversation 28638086.2169.2170
# No issues found.
#
# Checking reply-to chain of Conversation 26892383.21548.21548
# No issues found.
#
# Checking reply-to chain of Conversation 150842296.10681.9553
# No issues found.
#
# Checking reply-to chain of Conversation 149715841.2119.2119
# No issues found.
#
# Checking reply-to chain of Conversation 253247358.14213.14213
# No issues found.
#
# Checking reply-to chain of Conversation 248027055.10406.10406
# No issues found.
#
# Checking reply-to chain of Conversation 698991135.19168.19168
# No issues found.
#
# Checking reply-to chain of Conversation 689556831.64227.64227
# WARNING: ERROR: Missing utterance 689556831.64227.64227
# Checking reply-to chain of Conversation 506936178.87121.87121
# No issues found.
#
# Checking reply-to chain of Conversation 432489216.33831.33831
# No issues found.
#
# Checking reply-to chain of Conversation 433982536.24593.24593
# WARNING: ERROR: Missing utterance 433982536.24593.24593
# Checking reply-to chain of Conversation 433632295.20537.20537
# No issues found.
#
# Checking reply-to chain of Conversation 428511300.3026.521
# No issues found.
#
# Checking reply-to chain of Conversation 422670932.104060.104060
# No issues found.
#
# Checking reply-to chain of Conversation 254845438.45356.45356
# No issues found.
#
# Checking reply-to chain of Conversation 286310174.73107.73107
# No issues found.
#
# Checking reply-to chain of Conversation 358888060.4228.4228
# No issues found.
#
# Checking reply-to chain of Conversation 235563014.4360.4360
# No issues found.
#
# Checking reply-to chain of Conversation 244072026.22768.22465
# No issues found.
#
# Checking reply-to chain of Conversation 229782960.9230.9230
# No issues found.
#
# Checking reply-to chain of Conversation 33982772.724.724
# No issues found.
#
# Checking reply-to chain of Conversation 651692610.869.869
# No issues found.
#
# Checking reply-to chain of Conversation 761448773.7141.7141
# No issues found.
#
# Checking reply-to chain of Conversation 472067344.312.312
# No issues found.
#
# Checking reply-to chain of Conversation 162940568.6993.6993
# WARNING: ERROR: Missing utterance 162944951.7028.7028
# Checking reply-to chain of Conversation 125604776.5981.5981
# WARNING: ERROR: Missing utterance 162941679.7644.7948
# Checking reply-to chain of Conversation 10900408.9470.9470
# No issues found.
#
# Checking reply-to chain of Conversation 333853.0.0
# No issues found.
#
# Checking reply-to chain of Conversation 82917627.134310.134310
# No issues found.
#
# Checking reply-to chain of Conversation 82891418.131811.131811
# No issues found.
#
# Checking reply-to chain of Conversation 57210701.12247.12247
# No issues found.
#
# Checking reply-to chain of Conversation 16774729.0.0
# No issues found.
#
# Checking reply-to chain of Conversation 462206585.21475.21475
# No issues found.
#
# Checking reply-to chain of Conversation 426136415.11555.11555
# No issues found.
#
# Checking reply-to chain of Conversation 136580720.181876.181876
# No issues found.
#
# Checking reply-to chain of Conversation 132829693.152766.152766
# WARNING: ERROR: Missing utterance 132829693.152766.152766

# %%
print(len(train_pairs))
print(len(val_pairs))
print(len(test_pairs))
# Out:
# 2126
# 714
# 4470

# %%
# Validate the conversion by checking data size and some samples
print(len(test_pairs))
for p in test_pairs[:8]:
    print((p[2],p[2])+p)
# Out:
# 4470
# (0, 0, [['=', '=', 'UNK', '=', '=']], ['i', 'was', 'a', 'bit', 'disgruntled', 'you', 'recently', 'deleted', 'my', 'article', 'on', 'UNK', ',', 'especially', 'just', 'after', 'it', 'had', 'been', 'patrolled', '.', 'i', 'am', 'a', 'user', 'of', 'the', 'site', 'who', 'was', 'interested', 'in', 'its', 'message', 'and', 'felt', 'compelled', 'to', 'look', 'further', 'into', 'it', '(', 'seriously', ',', 'my', 'sources', 'are', 'the', 'first', 'couple', 'things', 'that', 'popped', 'up', 'after', 'a', 'google', 'search', ')', '.', 'i', 'am', 'a', 'bit', 'confused', 'why', 'a', 'well', 'written', 'and', 'documented', 'article', '(', 'my', 'first', ')', 'about', 'an'], 0, '240149353.16340.16332')
# (0, 0, [['=', '=', 'UNK', '=', '='], ['i', 'was', 'a', 'bit', 'disgruntled', 'you', 'recently', 'deleted', 'my', 'article', 'on', 'UNK', ',', 'especially', 'just', 'after', 'it', 'had', 'been', 'patrolled', '.', 'i', 'am', 'a', 'user', 'of', 'the', 'site', 'who', 'was', 'interested', 'in', 'its', 'message', 'and', 'felt', 'compelled', 'to', 'look', 'further', 'into', 'it', '(', 'seriously', ',', 'my', 'sources', 'are', 'the', 'first', 'couple', 'things', 'that', 'popped', 'up', 'after', 'a', 'google', 'search', ')', '.', 'i', 'am', 'a', 'bit', 'confused', 'why', 'a', 'well', 'written', 'and', 'documented', 'article', '(', 'my', 'first', ')', 'about', 'an']], ['well', ',', 'i', 'am', 'not', 'sure', 'if', 'the', 'article', 'meets', 'UNK', 'but', 'i', 'think', 'that', 'a', 'claim', 'of', '150', ',', '000', 'users', 'a', 'month', 'is', 'a', 'decent', 'claim', 'of', 'notability', 'and', 'there', 'are', 'a', 'few', 'mentions', 'in', 'rs', 'in', 'google', 'news', 'so', 'could', 'you', 'undelete', 'this', 'article', 'and', 'then', 'send', 'it', 'to', 'afd', 'where', 'its', 'notability', 'can', 'be', 'better', 'decided', '.', '-', "'", "'", "'", "'", "'", "'"], 0, '240153963.16690.16690')
# (0, 0, [['=', '=', 'UNK', '=', '='], ['i', 'was', 'a', 'bit', 'disgruntled', 'you', 'recently', 'deleted', 'my', 'article', 'on', 'UNK', ',', 'especially', 'just', 'after', 'it', 'had', 'been', 'patrolled', '.', 'i', 'am', 'a', 'user', 'of', 'the', 'site', 'who', 'was', 'interested', 'in', 'its', 'message', 'and', 'felt', 'compelled', 'to', 'look', 'further', 'into', 'it', '(', 'seriously', ',', 'my', 'sources', 'are', 'the', 'first', 'couple', 'things', 'that', 'popped', 'up', 'after', 'a', 'google', 'search', ')', '.', 'i', 'am', 'a', 'bit', 'confused', 'why', 'a', 'well', 'written', 'and', 'documented', 'article', '(', 'my', 'first', ')', 'about', 'an'], ['well', ',', 'i', 'am', 'not', 'sure', 'if', 'the', 'article', 'meets', 'UNK', 'but', 'i', 'think', 'that', 'a', 'claim', 'of', '150', ',', '000', 'users', 'a', 'month', 'is', 'a', 'decent', 'claim', 'of', 'notability', 'and', 'there', 'are', 'a', 'few', 'mentions', 'in', 'rs', 'in', 'google', 'news', 'so', 'could', 'you', 'undelete', 'this', 'article', 'and', 'then', 'send', 'it', 'to', 'afd', 'where', 'its', 'notability', 'can', 'be', 'better', 'decided', '.', '-', "'", "'", "'", "'", "'", "'"]], ['with', 'regard', 'to', 'the', 'article', "'", 's', 'lack', 'of', 'notability', 'and', 'a', 'lack', 'of', 'citations', ',', 'look', 'at', 'UNK', '.', 'it', 'has', 'only', 'one', 'citation', 'not', 'linking', 'to', 'itself', 'in', 'its', 'entire', 'article', '(', 'whereas', '6', 'similar', 'sources', 'are', 'used', 'on', 'UNK', ')', ',', 'and', 'it', 'has', 'never', 'logged', 'more', 'than', '10', ',', '000', 'unique', 'users', '/', 'month', 'in', 'its', 'short', 'history', '(', 'http', ':', '/', '/', 'www', '.', 'UNK', '.', 'com', '/', 'company', '/', 'UNK', ')', '.', 'a'], 0, '240786321.13311.13311')
# (0, 0, [['=', '=', '[', 'UNK', ':', 'UNK', ']', '=', '=']], ['i', 'want', 'this', 'topic', 'to', 'be', 'unprotected', ',', 'so', 'i', 'suggest', 'you', 'do', 'so', '.', 'do', 'you', 'wanna', 'go', 'to', 'war', 'with', 'me', '?'], 0, '241131342.18781.18523')
# (0, 0, [['=', '=', '[', 'UNK', ':', 'UNK', ']', '=', '='], ['i', 'want', 'this', 'topic', 'to', 'be', 'unprotected', ',', 'so', 'i', 'suggest', 'you', 'do', 'so', '.', 'do', 'you', 'wanna', 'go', 'to', 'war', 'with', 'me', '?']], ['don', "'", 't', 'be', 'absurd', '.', 'taking', 'it', 'to', 'your', 'talk', 'page', '.', '|'], 0, '241132175.18826.18826')
# (1, 1, [['=', '=', '[', 'UNK', ':', 'UNK', ']', '=', '='], ['i', 'want', 'this', 'topic', 'to', 'be', 'unprotected', ',', 'so', 'i', 'suggest', 'you', 'do', 'so', '.', 'do', 'you', 'wanna', 'go', 'to', 'war', 'with', 'me', '?'], ['don', "'", 't', 'be', 'absurd', '.', 'taking', 'it', 'to', 'your', 'talk', 'page', '.', '|']], ['are', 'you', 'a', 'moron', '?', 'did', 'you', 'even', 'bother', 'to', 'read', 'this', '?', 'i', "'", 'm', 'going', 'to', 'escalate', 'this', '.', 'i', 'suggest', 'you', 'learn', 'about', 'me', 'before', 'declaring', 'war', '.', '.', '.', '.'], 1, '241133122.18853.18853')
# (0, 0, [['=', '=', 'when', 'was', 'UNK', 'married', '?', '=', '=']], ['how', 'can', 'anyone', 'be', 'so', 'sure', 'they', 'were', 'married', 'from', '1977', 'until', '1983', 'or', 'whatever', 'it', 'was', '?', 'just', 'because', 'she', 'was', '15', ',', 'doesn', "'", 't', 'mean', 'she', 'married', 'in', 'the', 'year', 'she', 'turned', '15', ',', 'it', 'could', 'have', 'been', 'the', 'year', 'she', 'turned', '16', '.', 'are', 'we', 'even', 'sure', 'she', 'was', 'born', 'in', '1962', '?', 'how', 'do', 'we', 'know', 'she', 'married', 'UNK', 'in', '1983', '?', '–', '–'], 0, '463673734.2170.2155')
# (0, 0, [['=', '=', 'when', 'was', 'UNK', 'married', '?', '=', '='], ['how', 'can', 'anyone', 'be', 'so', 'sure', 'they', 'were', 'married', 'from', '1977', 'until', '1983', 'or', 'whatever', 'it', 'was', '?', 'just', 'because', 'she', 'was', '15', ',', 'doesn', "'", 't', 'mean', 'she', 'married', 'in', 'the', 'year', 'she', 'turned', '15', ',', 'it', 'could', 'have', 'been', 'the', 'year', 'she', 'turned', '16', '.', 'are', 'we', 'even', 'sure', 'she', 'was', 'born', 'in', '1962', '?', 'how', 'do', 'we', 'know', 'she', 'married', 'UNK', 'in', '1983', '?', '–', '–']], ['i', "'", 'm', 'not', 'sure', 'about', 'her', 'marriage', 'to', 'UNK', ',', 'although', 'i', 'remember', 'them', 'stating', 'when', 'they', 'were', 'about', 'to', 'go', 'travelling', '(', 'just', 'before', 'she', 'discovered', 'she', 'was', 'pregnant', 'with', 'UNK', ')', 'that', 'they', 'had', 'been', 'married', '26', 'years', 'and', 'this', 'was', 'in', 'august', '2009', '.'], 0, '463838506.2299.2299')

# %% [markdown]
# ## Part 3: define the model
#
# Next, we need to set up the individual components of the CRAFT framework: the utterance encoder, the context encoder, and the classification head (since we are only running inference on an already-trained model, we do not need to define the decoder here). Each component will be defined as a PyTorch `nn.Module`.

# %%
class EncoderRNN(nn.Module):
    """This module represents the utterance encoder component of CRAFT, responsible for creating vector representations of utterances"""
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size params are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = torch.nn.utils.rnn.pack_padded_sequence(embedded, input_lengths.cpu())
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = torch.nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden

class ContextEncoderRNN(nn.Module):
    """This module represents the context encoder component of CRAFT, responsible for creating an order-sensitive vector representation of conversation context"""
    def __init__(self, hidden_size, n_layers=1, dropout=0):
        super(ContextEncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        
        # only unidirectional GRU for context encoding
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=False)
        
    def forward(self, input_seq, input_lengths, hidden=None):
        # Pack padded batch of sequences for RNN module
        packed = torch.nn.utils.rnn.pack_padded_sequence(input_seq, input_lengths.cpu())
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = torch.nn.utils.rnn.pad_packed_sequence(outputs)
        # return output and final hidden state
        return outputs, hidden

class SingleTargetClf(nn.Module):
    """This module represents the CRAFT classifier head, which takes the context encoding and uses it to make a forecast"""
    def __init__(self, hidden_size, dropout=0.1):
        super(SingleTargetClf, self).__init__()
        
        self.hidden_size = hidden_size
        
        # initialize classifier
        self.layer1 = nn.Linear(hidden_size, hidden_size)
        self.layer1_act = nn.LeakyReLU()
        self.layer2 = nn.Linear(hidden_size, hidden_size // 2)
        self.layer2_act = nn.LeakyReLU()
        self.clf = nn.Linear(hidden_size // 2, num_classes) ############# changed 1 to 3 Number of output classes
        self.dropout = nn.Dropout(p=dropout)
        
    def forward(self, encoder_outputs, encoder_input_lengths):
        # from stackoverflow (https://stackoverflow.com/questions/50856936/taking-the-last-state-from-bilstm-bigru-in-pytorch)
        # First we unsqueeze seqlengths two times so it has the same number of
        # of dimensions as output_forward
        # (batch_size) -> (1, batch_size, 1)
        lengths = encoder_input_lengths.unsqueeze(0).unsqueeze(2)
        # Then we expand it accordingly
        # (1, batch_size, 1) -> (1, batch_size, hidden_size) 
        lengths = lengths.expand((1, -1, encoder_outputs.size(2)))

        # take only the last state of the encoder for each batch
        last_outputs = torch.gather(encoder_outputs, 0, lengths-1).squeeze()
        # forward pass through hidden layers
        layer1_out = self.layer1_act(self.layer1(self.dropout(last_outputs)))
        layer2_out = self.layer2_act(self.layer2(self.dropout(layer1_out)))
        # compute and return logits
        logits = self.clf(self.dropout(layer2_out)).squeeze()
        return logits

class Predictor(nn.Module):
    """This helper module encapsulates the CRAFT pipeline, defining the logic of passing an input through each consecutive sub-module."""
    def __init__(self, encoder, context_encoder, classifier):
        super(Predictor, self).__init__()
        self.encoder = encoder
        self.context_encoder = context_encoder
        self.classifier = classifier
        
    def forward(self, input_batch, dialog_lengths, dialog_lengths_list, utt_lengths, batch_indices, dialog_indices, batch_size, max_length):
        # Forward input through encoder model
        _, utt_encoder_hidden = self.encoder(input_batch, utt_lengths)
        
        # Convert utterance encoder final states to batched dialogs for use by context encoder
        context_encoder_input = makeContextEncoderInput(utt_encoder_hidden, dialog_lengths_list, batch_size, batch_indices, dialog_indices)
        
        # Forward pass through context encoder
        context_encoder_outputs, context_encoder_hidden = self.context_encoder(context_encoder_input, dialog_lengths)
        
        # Forward pass through classifier to get prediction logits
        logits = self.classifier(context_encoder_outputs, dialog_lengths)
        
        # Apply sigmoid activation
        predictions = F.softmax(logits, dim=1) ################### changed F.sigmoid(logits) to F.softmax(logits, dim=1)
        return predictions

def makeContextEncoderInput(utt_encoder_hidden, dialog_lengths, batch_size, batch_indices, dialog_indices):
    """The utterance encoder takes in utterances in combined batches, with no knowledge of which ones go where in which conversation.
       Its output is therefore also unordered. We correct this by using the information computed during tensor conversion to regroup
       the utterance vectors into their proper conversational order."""
    # first, sum the forward and backward encoder states
    utt_encoder_summed = utt_encoder_hidden[-2,:,:] + utt_encoder_hidden[-1,:,:]
    # we now have hidden state of shape [utterance_batch_size, hidden_size]
    # split it into a list of [hidden_size,] x utterance_batch_size
    last_states = [t.squeeze() for t in utt_encoder_summed.split(1, dim=0)]
    
    # create a placeholder list of tensors to group the states by source dialog
    states_dialog_batched = [[None for _ in range(dialog_lengths[i])] for i in range(batch_size)]
    
    # group the states by source dialog
    for hidden_state, batch_idx, dialog_idx in zip(last_states, batch_indices, dialog_indices):
        states_dialog_batched[batch_idx][dialog_idx] = hidden_state
        
    # stack each dialog into a tensor of shape [dialog_length, hidden_size]
    states_dialog_batched = [torch.stack(d) for d in states_dialog_batched]
    
    # finally, condense all the dialog tensors into a single zero-padded tensor
    # of shape [max_dialog_length, batch_size, hidden_size]
    return torch.nn.utils.rnn.pad_sequence(states_dialog_batched)

# %% [markdown]
# ## Part 4: define the evaluation procedure
#
# We're almost ready to run! The last component we need is some code for actually running the data through the full CRAFT pipeline. This includes actually converting the text input into tensors (we use the utilities defined in Part 1 to do this) then passing the resulting tensors through each CRAFT module batch-by-batch.

# %%
def train(input_variable, dialog_lengths, dialog_lengths_list, utt_lengths, batch_indices, dialog_indices, labels, # input/output arguments
          encoder, context_encoder, attack_clf,                                                                    # network arguments
          encoder_optimizer, context_encoder_optimizer, attack_clf_optimizer,                                      # optimization arguments
          batch_size, clip, max_length=MAX_LENGTH):                                                                # misc arguments

    # Zero gradients
    encoder_optimizer.zero_grad()
    context_encoder_optimizer.zero_grad()
    attack_clf_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    dialog_lengths = dialog_lengths.to(device)
    utt_lengths = utt_lengths.to(device)
    labels = labels.to(device)

    # Forward pass through utterance encoder
    _, utt_encoder_hidden = encoder(input_variable, utt_lengths)
    
    # Convert utterance encoder final states to batched dialogs for use by context encoder
    context_encoder_input = makeContextEncoderInput(utt_encoder_hidden, dialog_lengths_list, batch_size, batch_indices, dialog_indices)
    
    # Forward pass through context encoder
    context_encoder_outputs, _ = context_encoder(context_encoder_input, dialog_lengths)

    # Forward pass through classifier to get prediction logits
    logits = attack_clf(context_encoder_outputs, dialog_lengths)
    
    # Calculate loss
    loss = F.cross_entropy(logits, labels.long()) ######## from binary_cross_entropy_with_logits

    # Perform backpropatation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = torch.nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = torch.nn.utils.clip_grad_norm_(context_encoder.parameters(), clip)
    _ = torch.nn.utils.clip_grad_norm_(attack_clf.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    context_encoder_optimizer.step()
    attack_clf_optimizer.step()

    return loss.item()

def validate(dataset, encoder, context_encoder, predictor, voc, batch_size, device):
    # create a batch iterator for the given data
    batch_iterator = batchIterator(voc, dataset, batch_size, shuffle=False)
    # find out how many iterations we will need to cover the whole dataset
    n_iters = len(dataset) // batch_size + int(len(dataset) % batch_size > 0)
    # containers for full prediction results so we can compute accuracy at the end
    all_preds = []
    all_labels = []
    for iteration in range(1, n_iters+1):
        batch, batch_dialogs, _, true_batch_size = next(batch_iterator)
        # Extract fields from batch
        input_variable, dialog_lengths, utt_lengths, batch_indices, dialog_indices, labels, convo_ids, target_variable, mask, max_target_len = batch
        dialog_lengths_list = [len(x) for x in batch_dialogs]
        # run the model
        predictions, scores = evaluateBatch(encoder, context_encoder, predictor, voc, input_variable,
                                            dialog_lengths, dialog_lengths_list, utt_lengths, batch_indices, dialog_indices,
                                            true_batch_size, device)
        # aggregate results for computing accuracy at the end
        all_preds += [p.item() for p in predictions]
        all_labels += [l.item() for l in labels]
        print("Iteration: {}; Percent complete: {:.1f}%".format(iteration, iteration / n_iters * 100))

    # compute and return the accuracy
    return (np.asarray(all_preds) == np.asarray(all_labels)).mean()

def trainIters(voc, pairs, val_pairs, encoder, context_encoder, attack_clf,
               encoder_optimizer, context_encoder_optimizer, attack_clf_optimizer, embedding,
               n_iteration, batch_size, print_every, validate_every, clip):
    
    # create a batch iterator for training data
    batch_iterator = batchIterator(voc, pairs, batch_size)
    
    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0

    # Training loop
    print("Training...")
    # keep track of best validation accuracy - only save when we have a model that beats the current best
    best_acc = 0
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch, training_dialogs, _, true_batch_size = next(batch_iterator)
        # Extract fields from batch
        input_variable, dialog_lengths, utt_lengths, batch_indices, dialog_indices, labels, _, target_variable, mask, max_target_len = training_batch
        dialog_lengths_list = [len(x) for x in training_dialogs]

        # Run a training iteration with batch
        loss = train(input_variable, dialog_lengths, dialog_lengths_list, utt_lengths, batch_indices, dialog_indices, labels, # input/output arguments
                     encoder, context_encoder, attack_clf,                                                                    # network arguments
                     encoder_optimizer, context_encoder_optimizer, attack_clf_optimizer,                                      # optimization arguments
                     true_batch_size, clip)                                                                                   # misc arguments
        print_loss += loss
        
        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(iteration, iteration / n_iteration * 100, print_loss_avg))
            print_loss = 0

        # Evaluate on validation set
        if (iteration % validate_every == 0):
            print("Validating!")
            # put the network components into evaluation mode
            encoder.eval()
            context_encoder.eval()
            attack_clf.eval()
            
            predictor = Predictor(encoder, context_encoder, attack_clf)
            accuracy = validate(val_pairs, encoder, context_encoder, predictor, voc, batch_size, device)
            print("Validation set accuracy: {:.2f}%".format(accuracy * 100))

            # keep track of our best model so far
            if accuracy > best_acc:
                print("Validation accuracy better than current best; saving model...")
                best_acc = accuracy
                torch.save({
                    'iteration': iteration,
                    'en': encoder.state_dict(),
                    'ctx': context_encoder.state_dict(),
                    'atk_clf': attack_clf.state_dict(),
                    'en_opt': encoder_optimizer.state_dict(),
                    'ctx_opt': context_encoder_optimizer.state_dict(),
                    'atk_clf_opt': attack_clf_optimizer.state_dict(),
                    'loss': loss,
                    'voc_dict': voc.__dict__,
                    'embedding': embedding.state_dict()
                }, "finetuned_model.tar")
            
            # put the network components back into training mode
            encoder.train()
            context_encoder.train()
            attack_clf.train()

# %%
def evaluateBatch(encoder, context_encoder, predictor, voc, input_batch, dialog_lengths, 
                  dialog_lengths_list, utt_lengths, batch_indices, dialog_indices, batch_size, device, max_length=MAX_LENGTH):
    # Set device options
    input_batch = input_batch.to(device)
    dialog_lengths = dialog_lengths.to(device)
    utt_lengths = utt_lengths.to(device)
    # Predict future attack using predictor
    scores = predictor(input_batch, dialog_lengths, dialog_lengths_list, utt_lengths, batch_indices, dialog_indices, batch_size, max_length)
    predictions = (scores.argmax(dim=1)).float() ############ scores > 0.5 to scores.argmax(dim=1)
    return predictions, scores

def evaluateDataset(dataset, encoder, context_encoder, predictor, voc, batch_size, device):
    # create a batch iterator for the given data
    batch_iterator = batchIterator(voc, dataset, batch_size, shuffle=False)
    # find out how many iterations we will need to cover the whole dataset
    n_iters = len(dataset) // batch_size + int(len(dataset) % batch_size > 0)
    output_df = {
        "id": [],
        "prediction": [],
        "score": []
    }
    for iteration in range(1, n_iters+1):
        batch, batch_dialogs, _, true_batch_size = next(batch_iterator)
        # Extract fields from batch
        input_variable, dialog_lengths, utt_lengths, batch_indices, dialog_indices, labels, convo_ids, target_variable, mask, max_target_len = batch
        dialog_lengths_list = [len(x) for x in batch_dialogs]
        # run the model
        predictions, scores = evaluateBatch(encoder, context_encoder, predictor, voc, input_variable,
                                            dialog_lengths, dialog_lengths_list, utt_lengths, batch_indices, dialog_indices,
                                            true_batch_size, device)

        # format the output as a dataframe (which we can later re-join with the corpus)
        for i in range(true_batch_size):
            convo_id = convo_ids[i]
            pred = predictions[i].item()
            score = scores[i,1].item() ######################### grab position 1
            output_df["id"].append(convo_id)
            output_df["prediction"].append(pred)
            output_df["score"].append(score)
                
        print("Iteration: {}; Percent complete: {:.1f}%".format(iteration, iteration / n_iters * 100))

    return pd.DataFrame(output_df).set_index("id")

# %% [markdown]
# ## Part 5: build and run the model
#
# We finally have all the components we need! Now we can instantiate the CRAFT model components, load the trained weights, and run the evaluation.

# %%
# Fix random state (affect native Python code only, does not affect PyTorch and hence does not guarantee reproducibility)
random.seed(2019)

# Tell torch to use GPU. Note that if you are running this notebook in a non-GPU environment, you can change 'cuda' to 'cpu' to get the code to run.
device = torch.device('cuda')

print("Loading saved parameters...")
if not os.path.isfile("model.tar"):
    print("\tDownloading trained CRAFT...")
    urlretrieve(MODEL_URL, "model.tar")
    print("\t...Done!")
checkpoint = torch.load("model.tar")
# If running in a non-GPU environment, you need to tell PyTorch to convert the parameters to CPU tensor format.
# To do so, replace the previous line with the following:
#checkpoint = torch.load("model.tar", map_location=torch.device('cpu'))
encoder_sd = checkpoint['en']
context_sd = checkpoint['ctx']
embedding_sd = checkpoint['embedding']
voc.__dict__ = checkpoint['voc_dict']

print('Building encoders, decoder, and classifier...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
embedding.load_state_dict(embedding_sd)
# Initialize utterance and context encoders
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
context_encoder = ContextEncoderRNN(hidden_size, context_encoder_n_layers, dropout)
encoder.load_state_dict(encoder_sd)
context_encoder.load_state_dict(context_sd)
# Initialize classifier
attack_clf = SingleTargetClf(hidden_size, dropout)
# Use appropriate device
encoder = encoder.to(device)
context_encoder = context_encoder.to(device)
attack_clf = attack_clf.to(device)
print('Models built and ready to go!')

# Compute the number of training iterations we will need in order to achieve the number of epochs specified in the settings at the start of the notebook
n_iter_per_epoch = len(train_pairs) // batch_size + int(len(train_pairs) % batch_size == 1)
n_iteration = n_iter_per_epoch * 30 #finetune_epochs

# Put dropout layers in train mode
encoder.train()
context_encoder.train()
attack_clf.train()

# Initialize optimizers
print('Building optimizers...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=labeled_learning_rate)
context_encoder_optimizer = optim.Adam(context_encoder.parameters(), lr=labeled_learning_rate)
attack_clf_optimizer = optim.Adam(attack_clf.parameters(), lr=labeled_learning_rate)

# Run training iterations, validating after every epoch
print("Starting Training!")
print("Will train for {} iterations".format(n_iteration))
trainIters(voc, train_pairs, val_pairs, encoder, context_encoder, attack_clf,
           encoder_optimizer, context_encoder_optimizer, attack_clf_optimizer, embedding,
           n_iteration, batch_size, print_every, n_iter_per_epoch, clip)
# Out:
# Loading saved parameters...
# 	Downloading trained CRAFT...
# 	...Done!
# Building encoders, decoder, and classifier...
# Models built and ready to go!
# Building optimizers...
# Starting Training!
# Will train for 990 iterations
# Initializing ...
# Training...
# Iteration: 10; Percent complete: 1.0%; Average loss: 0.6939
# Iteration: 20; Percent complete: 2.0%; Average loss: 0.6870
# Iteration: 30; Percent complete: 3.0%; Average loss: 0.6818
# Validating!
# Iteration: 1; Percent complete: 8.3%
# Iteration: 2; Percent complete: 16.7%
# Iteration: 3; Percent complete: 25.0%
# Iteration: 4; Percent complete: 33.3%
# Iteration: 5; Percent complete: 41.7%
# Iteration: 6; Percent complete: 50.0%
# Iteration: 7; Percent complete: 58.3%
# Iteration: 8; Percent complete: 66.7%
# Iteration: 9; Percent complete: 75.0%
# Iteration: 10; Percent complete: 83.3%
# Iteration: 11; Percent complete: 91.7%
# Iteration: 12; Percent complete: 100.0%
# Validation set accuracy: 63.45%
# Validation accuracy better than current best; saving model...
# Iteration: 40; Percent complete: 4.0%; Average loss: 0.6754
# Iteration: 50; Percent complete: 5.1%; Average loss: 0.6653
# Iteration: 60; Percent complete: 6.1%; Average loss: 0.6590
# Validating!
# Iteration: 1; Percent complete: 8.3%
# Iteration: 2; Percent complete: 16.7%
# Iteration: 3; Percent complete: 25.0%
# Iteration: 4; Percent complete: 33.3%
# Iteration: 5; Percent complete: 41.7%
# Iteration: 6; Percent complete: 50.0%
# Iteration: 7; Percent complete: 58.3%
# Iteration: 8; Percent complete: 66.7%
# Iteration: 9; Percent complete: 75.0%
# Iteration: 10; Percent complete: 83.3%
# Iteration: 11; Percent complete: 91.7%
# Iteration: 12; Percent complete: 100.0%
# Validation set accuracy: 63.45%
# Iteration: 70; Percent complete: 7.1%; Average loss: 0.6528
# Iteration: 80; Percent complete: 8.1%; Average loss: 0.6394
# Iteration: 90; Percent complete: 9.1%; Average loss: 0.6302
# Validating!
# Iteration: 1; Percent complete: 8.3%
# Iteration: 2; Percent complete: 16.7%
# Iteration: 3; Percent complete: 25.0%
# Iteration: 4; Percent complete: 33.3%
# Iteration: 5; Percent complete: 41.7%
# Iteration: 6; Percent complete: 50.0%
# Iteration: 7; Percent complete: 58.3%
# Iteration: 8; Percent complete: 66.7%
# Iteration: 9; Percent complete: 75.0%
# Iteration: 10; Percent complete: 83.3%
# Iteration: 11; Percent complete: 91.7%
# Iteration: 12; Percent complete: 100.0%
# Validation set accuracy: 63.03%
# Iteration: 100; Percent complete: 10.1%; Average loss: 0.6217
# Iteration: 110; Percent complete: 11.1%; Average loss: 0.6108
# Iteration: 120; Percent complete: 12.1%; Average loss: 0.5938
# Iteration: 130; Percent complete: 13.1%; Average loss: 0.5782
# Validating!
# Iteration: 1; Percent complete: 8.3%
# Iteration: 2; Percent complete: 16.7%
# Iteration: 3; Percent complete: 25.0%
# Iteration: 4; Percent complete: 33.3%
# Iteration: 5; Percent complete: 41.7%
# Iteration: 6; Percent complete: 50.0%
# Iteration: 7; Percent complete: 58.3%
# Iteration: 8; Percent complete: 66.7%
# Iteration: 9; Percent complete: 75.0%
# Iteration: 10; Percent complete: 83.3%
# Iteration: 11; Percent complete: 91.7%
# Iteration: 12; Percent complete: 100.0%
# Validation set accuracy: 64.57%
# Validation accuracy better than current best; saving model...
# Iteration: 140; Percent complete: 14.1%; Average loss: 0.5563
# Iteration: 150; Percent complete: 15.2%; Average loss: 0.5516
# Iteration: 160; Percent complete: 16.2%; Average loss: 0.5372
# Validating!
# Iteration: 1; Percent complete: 8.3%
# Iteration: 2; Percent complete: 16.7%
# Iteration: 3; Percent complete: 25.0%
# Iteration: 4; Percent complete: 33.3%
# Iteration: 5; Percent complete: 41.7%
# Iteration: 6; Percent complete: 50.0%
# Iteration: 7; Percent complete: 58.3%
# Iteration: 8; Percent complete: 66.7%
# Iteration: 9; Percent complete: 75.0%
# Iteration: 10; Percent complete: 83.3%
# Iteration: 11; Percent complete: 91.7%
# Iteration: 12; Percent complete: 100.0%
# Validation set accuracy: 64.01%
# Iteration: 170; Percent complete: 17.2%; Average loss: 0.5001
# Iteration: 180; Percent complete: 18.2%; Average loss: 0.4848
# Iteration: 190; Percent complete: 19.2%; Average loss: 0.4819
# Validating!
# Iteration: 1; Percent complete: 8.3%
# Iteration: 2; Percent complete: 16.7%
# Iteration: 3; Percent complete: 25.0%
# Iteration: 4; Percent complete: 33.3%
# Iteration: 5; Percent complete: 41.7%
# Iteration: 6; Percent complete: 50.0%
# Iteration: 7; Percent complete: 58.3%
# Iteration: 8; Percent complete: 66.7%
# Iteration: 9; Percent complete: 75.0%
# Iteration: 10; Percent complete: 83.3%
# Iteration: 11; Percent complete: 91.7%
# Iteration: 12; Percent complete: 100.0%
# Validation set accuracy: 65.27%
# Validation accuracy better than current best; saving model...
# Iteration: 200; Percent complete: 20.2%; Average loss: 0.4693
# Iteration: 210; Percent complete: 21.2%; Average loss: 0.4519
# Iteration: 220; Percent complete: 22.2%; Average loss: 0.4311
# Iteration: 230; Percent complete: 23.2%; Average loss: 0.4127
# Validating!
# Iteration: 1; Percent complete: 8.3%
# Iteration: 2; Percent complete: 16.7%
# Iteration: 3; Percent complete: 25.0%
# Iteration: 4; Percent complete: 33.3%
# Iteration: 5; Percent complete: 41.7%
# Iteration: 6; Percent complete: 50.0%
# Iteration: 7; Percent complete: 58.3%
# Iteration: 8; Percent complete: 66.7%
# Iteration: 9; Percent complete: 75.0%
# Iteration: 10; Percent complete: 83.3%
# Iteration: 11; Percent complete: 91.7%
# Iteration: 12; Percent complete: 100.0%
# Validation set accuracy: 64.57%
# Iteration: 240; Percent complete: 24.2%; Average loss: 0.4178
# Iteration: 250; Percent complete: 25.3%; Average loss: 0.3601
# Iteration: 260; Percent complete: 26.3%; Average loss: 0.3901
# Validating!
# Iteration: 1; Percent complete: 8.3%
# Iteration: 2; Percent complete: 16.7%
# Iteration: 3; Percent complete: 25.0%
# Iteration: 4; Percent complete: 33.3%
# Iteration: 5; Percent complete: 41.7%
# Iteration: 6; Percent complete: 50.0%
# Iteration: 7; Percent complete: 58.3%
# Iteration: 8; Percent complete: 66.7%
# Iteration: 9; Percent complete: 75.0%
# Iteration: 10; Percent complete: 83.3%
# Iteration: 11; Percent complete: 91.7%
# Iteration: 12; Percent complete: 100.0%
# Validation set accuracy: 64.15%
# Iteration: 270; Percent complete: 27.3%; Average loss: 0.3787
# Iteration: 280; Percent complete: 28.3%; Average loss: 0.3607
# Iteration: 290; Percent complete: 29.3%; Average loss: 0.3247
# Validating!
# Iteration: 1; Percent complete: 8.3%
# Iteration: 2; Percent complete: 16.7%
# Iteration: 3; Percent complete: 25.0%
# Iteration: 4; Percent complete: 33.3%
# Iteration: 5; Percent complete: 41.7%
# Iteration: 6; Percent complete: 50.0%
# Iteration: 7; Percent complete: 58.3%
# Iteration: 8; Percent complete: 66.7%
# Iteration: 9; Percent complete: 75.0%
# Iteration: 10; Percent complete: 83.3%
# Iteration: 11; Percent complete: 91.7%
# Iteration: 12; Percent complete: 100.0%
# Validation set accuracy: 64.57%
# Iteration: 300; Percent complete: 30.3%; Average loss: 0.3369
# Iteration: 310; Percent complete: 31.3%; Average loss: 0.3125
# Iteration: 320; Percent complete: 32.3%; Average loss: 0.3064
# Iteration: 330; Percent complete: 33.3%; Average loss: 0.3001
# Validating!
# Iteration: 1; Percent complete: 8.3%
# Iteration: 2; Percent complete: 16.7%
# Iteration: 3; Percent complete: 25.0%
# Iteration: 4; Percent complete: 33.3%
# Iteration: 5; Percent complete: 41.7%
# Iteration: 6; Percent complete: 50.0%
# Iteration: 7; Percent complete: 58.3%
# Iteration: 8; Percent complete: 66.7%
# Iteration: 9; Percent complete: 75.0%
# Iteration: 10; Percent complete: 83.3%
# Iteration: 11; Percent complete: 91.7%
# Iteration: 12; Percent complete: 100.0%
# Validation set accuracy:
# 192640416.19036.19036         0.0  0.006237
# 190189346.16645.16645         0.0  0.010416
# 203898053.13222.13222         1.0  0.998218
# 484672227.2434.2434           0.0  0.004200
# 465344124.2616.2616           1.0  0.858374

# %% [markdown]
# ## Part 6: merge predictions back into corpus and evaluate
#
# Now that the hard part is done, all that is left to do is to evaluate the predictions. Since the predictions are in no particular order, we will first merge each prediction back into the source corpus, and then evaluate each conversation according to the order of utterances within that conversation.

# %%
# We will add a metadata entry to each test-set utterance signifying whether it was FORECAST to be a derailment.
# Note that there is an important subtlety in how this metadata field is to be interpreted - the forecast for a given
# utterance is made BEFORE the model actually sees the utterance. That is, the forecast does not mean "the model thinks
# this utterance *is* a derailment" but rather that "based on the context of all preceding utterances, the model predicted,
# prior to actually seeing this utterance, that this utterance *would be* a derailment".
for convo in corpus.iter_conversations():
    # only consider test set conversations (we did not make predictions for the other ones)
    if convo.meta['split'] == "test":
        for utt in convo.iter_utterances():
            if utt.id in forecasts_df.index:
                utt.meta['forecast_score'] = forecasts_df.loc[utt.id].score

# %%
# Finally, we can use the forecast-annotated corpus to compute the forecast accuracy.
# Though we have an individual forecast per utterance, ground truth is at the conversation level:
# either a conversation derails or it does not. Thus, forecast accuracy is computed as follows:
#   - True positives are cases that actually derail, for which the model made at least one positive forecast ANYTIME prior to derailment
#   - False positives are cases that don't derail but for which the model made at least one positive forecast
#   - False negatives are cases that derail but for which the model made no positive forecasts prior to derailment
#   - True negatives are cases that don't derail, for which the model made no positive forecasts
# Note that by construction, the last comment of each conversation is the one marked as derailment, and that our earlier code was therefore
# set up to not look at the last comment, meaning that all forecasts we obtained are forecasts made prior to derailment. This simplifies
# the computation of forecast accuracy as we now do not need to explicitly consider when a forecast was made.

conversational_forecasts_df = {
    "convo_id": [],
    "label": [],
    "score": [],
    "prediction": []
}

for convo in corpus.iter_conversations():
    if convo.meta['split'] == "test":
        conversational_forecasts_df['convo_id'].append(convo.id)
        conversational_forecasts_df['label'].append(int(convo.meta['conversation_has_personal_attack']))
        forecast_scores = [utt.meta['forecast_score'] for utt in convo.iter_utterances() if 'forecast_score' in utt.meta]
        conversational_forecasts_df['score'] = np.max(forecast_scores)
        conversational_forecasts_df['prediction'].append(int(np.max(forecast_scores) > FORECAST_THRESH))

conversational_forecasts_df = pd.DataFrame(conversational_forecasts_df).set_index("convo_id")
print((conversational_forecasts_df.label == conversational_forecasts_df.prediction).mean())
# Out:
# [0.5444992184638977, 0.1724042147397995, 0.004018262028694153]
# [0.5202211737632751, 0.06126021593809128, 0.7370046973228455]
# [0.34986820816993713, 0.024098975583910942, 0.00429548230022192, 0.004200256895273924]
# [0.5821068286895752, 0.42279478907585144, 0.19549117982387543, 0.8583735227584839]
# [0.3606700599193573, 0.05508307367563248, 0.003052240237593651, 0.0017321092309430242, 0.036299414932727814]
# [0.38526979088783264, 0.17191675305366516, 0.01778290420770645, 0.9835145473480225]
# [0.3512697219848633, 0.03752577677369118, 0.002304091351106763, 0.005256766453385353, 0.11527670174837112, 0.7451597452163696, 0.9829888939857483]
# [0.2378510683774948, 0.14331410825252533, 0.023699533194303513, 0.010280875489115715, 0.0023323579225689173]
# [0.6430383324623108, 0.96126389503479, 0.9976759552955627, 0.9963827133178711, 0.9990569949150085, 0.9986978769302368]
# [0.37125974893569946, 0.40671584010124207, 0.014188176952302456, 0.007999853231012821, 0.007243583910167217]
# [0.45423614978790283, 0.15611742436885834, 0.022465063259005547, 0.030364995822310448, 0.004885715898126364, 0.03171075880527496, 0.7216581702232361]
# [0.29814398288726807, 0.23688794672489166, 0.14722146093845367, 0.11011379212141037, 0.08769158273935318, 0.04137999191880226]
# [0.25121286511421204, 0.45076847076416016, 0.5523548126220703, 0.7324320673942566, 0.9985582232475281, 0.999868631362915]
# [0.39661478996276855, 0.06633259356021881, 0.009888563305139542, 0.0022822555620223284, 0.0028866808861494064, 0.008496507070958614, 0.12255523353815079, 0.9605618715286255, 0.9982717037200928, 0.9995720982551575]
# [0.4108932912349701, 0.03214474022388458, 0.010516464710235596, 0.42090144753456116, 0.7946409583091736, 0.8262026309967041, 0.9974978566169739]
# [0.26744315028190613, 0.2288513481616974, 0.05788375064730644, 0.003406513249501586, 0.004500659182667732, 0.005220675375312567]
# [0.36248067021369934, 0.0480763278901577, 0.9135359525680542, 0.7909293174743652, 0.9780390858650208, 0.9012932181358337, 0.8760005235671997, 0.7861912250518799, 0.9982510209083557]
# [0.47545236349105835, 0.07199203968048096, 0.07278913259506226, 0.02303960546851158, 0.010671786032617092, 0.005420600529760122, 0.021985001862049103, 0.015827450901269913, 0.34365856647491455]
# [0.47912147641181946, 0.6945201754570007, 0.9922978281974792, 0.9974675178527832, 0.9997760653495789]
# [0.2868250608444214, 0.058672867715358734, 0.2788017988204956, 0.10209818929433823, 0.03803549334406853]
# [0.7296801805496216, 0.8985666036605835, 0.9978171586990356, 0.9997019171714783, 0.9996945858001709, 0.9991899132728577]
# [0]
# 0.6154761904761905

# %%
# in addition to accuracy, we can also consider applying other metrics at the conversation level, such as precision/recall
def get_pr_stats(preds, labels):
    tp = ((labels==1)&(preds==1)).sum()
    fp = ((labels==0)&(preds==1)).sum()
    tn = ((labels==0)&(preds==0)).sum()
    fn = ((labels==1)&(preds==0)).sum()
    print("Precision = {0:.4f}, recall = {1:.4f}".format(tp / (tp + fp), tp / (tp + fn)))
    print("False positive rate =", fp / (fp + tn))
    print("F1 =", 2 / (((tp + fp) / tp) + ((tp + fn) / tp)))

get_pr_stats(conversational_forecasts_df.prediction, conversational_forecasts_df.label)
# Out:
# Precision = 0.6075, recall = 0.6524
# False positive rate = 0.42142857142857143
# F1 = 0.6291618828932262

# %% [markdown]
# ## Part 7: model analysis: how early is early warning?
#
# The goal of CRAFT is to forecast outcomes in advance, but how far in advance does it typically make its prediction? Following the paper, we measure this in two ways: the number of *comments* between the first prediction and the actual derailment, and how much *elapsed time* that gap actually translates to.

# %%
comments_until_derail = {} # store the "number of comments until derailment" metric for each conversation
time_until_derail = {} # store the "time until derailment" metric for each conversation

for convo in corpus.iter_conversations():
    if convo.meta['split'] == "test" and convo.meta['conversation_has_personal_attack']:
        # filter out the section header as usual
        utts = [utt for utt in convo.iter_utterances() if not utt.meta['is_section_header']]
        # by construction, the last comment is the one with the personal attack
        derail_idx = len(utts) - 1
        # now scan the utterances in order until we find the first derailment prediction (if any)
        for idx in range(1, len(utts)):
            if utts[idx].meta['forecast_score'] > FORECAST_THRESH:
                # recall that the forecast_score meta field specifies what CRAFT thought this comment would look like BEFORE it
                # saw this comment. So the actual CRAFT forecast is made during the previous comment; we account for this by 
                # subtracting 1 from idx
                comments_until_derail[convo.id] = derail_idx - (idx-1)
                time_until_derail[convo.id] = utts[derail_idx].timestamp - utts[(idx-1)].timestamp
                break

# compute some quick statistics about the distribution of the "number of comments until derailment" metric
comments_until_derail_vals = np.asarray(list(comments_until_derail.values()))
print(np.min(comments_until_derail_vals), np.max(comments_until_derail_vals), np.median(comments_until_derail_vals), np.mean(comments_until_derail_vals))

# compute some quick statistics about the distribution of the "time until derailment" metric
# note that since timestamps are in seconds, we convert to hours by dividing by 3600, to make it more human readable
time_until_derail_vals = np.asarray(list(time_until_derail.values())) / 3600
print(np.min(time_until_derail_vals), np.max(time_until_derail_vals), np.median(time_until_derail_vals), np.mean(time_until_derail_vals))

# visualize the distribution of "number of comments until derailment" as a histogram (reproducing Figure 4 from the paper)
plt.rcParams['figure.figsize'] = (10.0, 5.0)
plt.rcParams['font.size'] = 24
plt.hist(comments_until_derail_vals, bins=range(1, np.max(comments_until_derail_vals)), density=True)
plt.xlim(1,10)
plt.xticks(np.arange(1,10)+0.5, np.arange(1,10))
plt.yticks(np.arange(0,0.25,0.05), np.arange(0,25,5))
plt.xlabel("Number of comments elapsed")
plt.ylabel("% of conversations")
plt.show()

# %%
# compute some quick statistics about the distribution of the "number of comments until derailment" metric
comments_until_derail_vals = np.asarray(list(comments_until_derail.values()))
print(np.min(comments_until_derail_vals), np.max(comments_until_derail_vals), np.median(comments_until_derail_vals), np.mean(comments_until_derail_vals))

# %%
# compute some quick statistics about the distribution of the "time until derailment" metric
# note that since timestamps are in seconds, we convert to hours by dividing by 3600, to make it more human readable
time_until_derail_vals = np.asarray(list(time_until_derail.values())) / 3600
print(np.min(time_until_derail_vals), np.max(time_until_derail_vals), np.median(time_until_derail_vals), np.mean(time_until_derail_vals))

# %%
# visualize the distribution of "number of comments until derailment" as a histogram (reproducing Figure 4 from the paper)
plt.rcParams['figure.figsize'] = (10.0, 5.0)
plt.rcParams['font.size'] = 24
plt.hist(comments_until_derail_vals, bins=range(1, np.max(comments_until_derail_vals)), density=True)
plt.xlim(1,10)
plt.xticks(np.arange(1,10)+0.5, np.arange(1,10))
plt.yticks(np.arange(0,0.25,0.05), np.arange(0,25,5))
plt.xlabel("Number of comments elapsed")
plt.ylabel("% of conversations")
plt.show()
